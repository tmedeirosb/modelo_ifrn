# %% [markdown]
# - definir linha que divide os clusters (alunos bons e ruins)
# - verificar se há diferença estatísticas entre os clusters de alunos ruins entre as disciplinas, tal como entre os alunos bons.
# - verificar se há diferença estatísticas entre os clusters de alunos ruins entre os cursos (espanhol presencial e a distancia, segurança do trabalho presencial e a distância), tal como entre os alunos bons
# - para cada cluster fazer a análise de PCA dos atributos de caracterização social.
# -  índice que indique se um determinado aluno pertence quantas vezes a cada grupo. Por exemplo:

# %%
#import os pacotes utilizados
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
#from pylab import *
#from scipy.optimize import curve_fit
from sklearn.cluster import KMeans
import scipy.spatial as sp, scipy.cluster.hierarchy as hc

# %%
#import os dataframe do IFRN
df_aluno = pd.read_json('thiago/Aluno.json')
df_Caracterizacao = pd.read_json("thiago/Caracterizacao.json")
df_Raca = pd.read_json("thiago/Raca.json")
df_EstadoCivil = pd.read_json("thiago/EstadoCivil.json")
df_SituacaoMatricula = pd.read_json("thiago/SituacaoMatricula.json")
df_Disciplina = pd.read_json("thiago/Disciplina.json")
df_NivelEscolaridade = pd.read_json("thiago/NivelEscolaridade.json")
df_Notas = pd.read_json("thiago/Notas.json")
df_SituacaoDisciplina = pd.read_json("thiago/SituacaoDisciplina.json")
df_CursoCampus = pd.read_json('thiago/CursoCampus.json')
df_MatriculaPeriodo = pd.read_json("thiago/MatriculaPeriodo.json")

# %%
"""
é criado um novo frame com a junção das notas e disciplinas e restringindo que apenas disciplinas com mais de 60 instâncias, 
uma vez que cada disciplina será dividade em dois grupos (alunos aprovado e reprovados) e cada grupo desse deve ter 
ao menos 30 instâncias devido a teoria do limite central 
"""
#merge entre frame notas e disciplinas
print(df_Notas.shape)
merged = pd.merge(df_Notas, df_Disciplina, left_on="disciplina_id", right_on="id", suffixes=["_L", "_R"])
print(merged.shape)

#filtra disciplinas com registros maiores que 60 - 2 classes com min de 30 (teorema do limite central pg. 55 Laura Igual)
merged = merged.groupby('disciplina_id').filter(lambda x: len(x) > 60)
print(merged.shape)

#agrupando e gerando as estatisticas da media final
merged.groupby("descricao_historico")['media_final'].describe().unstack()
# Out:
# (36436, 6)
# (36436, 9)
# (34514, 9)
#                                                      count       mean  \
# descricao_historico
# Análise e Elaboração de Materiais de E/LE             68.0  50.970588
# Atividades de Metodologia do Ensino de ELE I          79.0  61.278481
# Controle Ambiental(60H)                              364.0  55.629121
# Cultura Hispânica I                                  122.0  50.934426
# Desenho Técnico(60H)                                1369.0  55.860482
# Desenvolvimento de Projeto Integrador                824.0  66.637136
# Desenvolvimento de Projetos Integradores I           166.0  55.728916
# Desenvolvimento de Projetos Integradores II           90.0  58.055556
# Dialetologia do Espanhol                             100.0  56.780000
# Didática                                             164.0  64.804878
# Direito Aplicado à Segurança e Saúde no Trabalh...   845.0  51.817751
# EAD: Fundamentos e Práticas Aplicados a Educação     145.0  75.951724
# Educação Inclusiva                                   136.0  53.139706
# Ergonomia(60H)                                       751.0  59.797603
# Estatística Aplicada à Segurança do Trabalho(30H)   1401.0  50.673091
# Extensão com TCC                                     163.0  66.631902
# Filosofia da Linguagem                               105.0  49.228571
# Filosofia, Ciência e Tecnologia                      984.0  65.991870
# Fonética e Fonologia do Espanhol I                   236.0  57.885593
# Fonética e Fonologia do Espanhol II                  147.0  63.591837
# Fundamentos Históricos e Filosóficos da Educação     295.0  55.467797
# Fundamentos Sociopolíticos e Econômicos da Educ...   192.0  58.166667
# Fundamentos da Literatura                            208.0  47.788462
# Fundamentos da Literatura Ocidental                   84.0  37.285714
# Fundamentos e práticas na EAD(15H)                   992.0  55.873992
# Gestão de Saúde e Segurança Ocupacional(60H)         925.0  49.987027
# Gestão organizacional(30H)                           371.0  60.026954
# Higiene Ocupacional(60H)                             844.0  49.204976
# História da Língua Espanhola                         244.0  40.348361
# Informática                                          194.0  70.407216
# ...                                                    ...        ...
# Língua Portuguesa                                   1668.0  50.992806
# Metodologia da Educação a Distância                   99.0  51.242424
# Metodologia do Ensino de Espanhol como LE             83.0  56.831325
# Metodologia do Trabalho Científico                   205.0  54.873171
# Morfossintaxe I                                      236.0  49.885593
# Morfossintaxe II                                     148.0  60.155405
# Organização e Gestão da Educação Brasileira          165.0  50.193939
# Prevenção e Combate à Incêndio (Sinistro)            271.0  65.597786
# Prevenção e Combate à Sinistro(60H)                   87.0  56.494253
# Prevenção e Controle de Perdas(90H)                  363.0  58.834711
# Primeiros Socorros(60H)                             1001.0  60.680320
# Psicologia Geral(30H)                               1363.0  55.335290
# Psicologia da Educação                               191.0  63.324607
# Psicologia do Trabalho(60H)                         1135.0  51.478414
# Qualidade de Vida e Trabalho                         356.0  63.089888
# Saúde Ocupacional(30H)                              1081.0  59.548566
# Segurança do Trabalho(60H)                           744.0  60.388441
# Seminário de Iniciação à Pesquisa(30H)               983.0  66.813835
# Seminário de Integração Acadêmica                    270.0  52.222222
# Seminário de Integração Acadêmica(10H)              1111.0   0.000000
# Seminário de Orientação de Estágio Docente I          77.0  54.259740
# Seminário de Orientação de Estágio Docente III        63.0  50.174603
# Seminário de Orientação de Pesquisa I                 84.0  34.619048
# Seminário de Orientação de Projeto Integrador I      142.0  50.929577
# Seminário de Orientação de Projeto Integrador II     107.0  60.046729
# Seminário de Orientação para a Prática Profissi...   772.0  55.191710
# Seminário de Orientação para a Prática Profissi...   359.0  63.916435
# Sociologia do Trabalho                              1070.0  55.169159
# Teoria da Literatura I                               162.0  46.938272
# Teoria da Literatura II                               74.0  59.189189
#
#                                                           std  min    25%  \
# descricao_historico
# Análise e Elaboração de Materiais de E/LE           37.422545  0.0  11.75
# Atividades de Metodologia do Ensino de ELE I        36.419541  0.0  24.50
# Controle Ambiental(60H)                             29.439059  0.0  35.75
# Cultura Hispânica I                                 33.835220  0.0  13.25
# Desenho Técnico(60H)                                38.401678  0.0   0.00
# Desenvolvimento de Projeto Integrador               37.639502  0.0  60.00
# Desenvolvimento de Projetos Integradores I          41.187436  0.0   0.00
# Desenvolvimento de Projetos Integradores II         43.854807  0.0   0.00
# Dialetologia do Espanhol                            28.324091  0.0  35.00
# Didática                                            30.956506  0.0  62.75
# Direito Aplicado à Segurança e Saúde no Trabalh...  28.135882  0.0  32.00
# EAD: Fundamentos e Práticas Aplicados a Educação    17.836577  0.0  69.00
# Educação Inclusiva                                  35.548438  0.0   9.50
# Ergonomia(60H)                                      31.852603  0.0  52.50
# Estatística Aplicada à Segurança do Trabalho(30H)   36.344603  0.0   0.00
# Extensão com TCC                                    29.218833  0.0  62.00
# Filosofia da Linguagem                              29.471387  0.0  22.00
# Filosofia, Ciência e Tecnologia                     30.869725  0.0  61.00
# Fonética e Fonologia do Espanhol I                  25.357185  0.0  43.00
# Fonética e Fonologia do Espanhol II                 26.237262  0.0  60.00
# Fundamentos Históricos e Filosóficos da Educação    33.863644  0.0  29.00
# Fundamentos Sociopolíticos e Econômicos da Educ...  32.938676  0.0  31.50
# Fundamentos da Literatura                           33.571086  0.0  12.75
# Fundamentos da Literatura Ocidental                 39.138177  0.0   0.00
# Fundamentos e práticas na EAD(15H)                  31.979011  0.0  35.75
# Gestão de Saúde e Segurança Ocupacional(60H)        35.615914  0.0   9.00
# Gestão organizacional(30H)                          28.133549  0.0  54.00
# Higiene Ocupacional(60H)                            32.005737  0.0  14.00
# História da Língua Espanhola                        30.792374  0.0  10.00
# Informática                                         22.474952  0.0  65.00
# ...                                                       ...  ...    ...
# Língua Portuguesa                                   34.044115  0.0   0.00
# Metodologia da Educação a Distância                 35.468034  0.0   7.50
# Metodologia do Ensino de Espanhol como LE           31.764307  0.0  24.50
# Metodologia do Trabalho Científico                  32.266104  0.0  26.00
# Morfossintaxe I                                     31.862999  0.0  16.00
# Morfossintaxe II                                    25.089151  0.0  59.25
# Organização e Gestão da Educação Brasileira         29.862673  0.0  24.00
# Prevenção e Combate à Incêndio (Sinistro)           26.563492  0.0  61.00
# Prevenção e Combate à Sinistro(60H)                 29.038016  0.0  50.50
# Prevenção e Controle de Perdas(90H)                 31.323657  0.0  40.00
# Primeiros Socorros(60H)                             29.818915  0.0  58.00
# Psicologia Geral(30H)                               38.641845  0.0   0.00
# Psicologia da Educação                              28.856986  0.0  60.00
# Psicologia do Trabalho(60H)                         31.028564  0.0  26.50
# Qualidade de Vida e Trabalho                        26.340732  0.0  60.00
# Saúde Ocupacional(30H)                              28.127713  0.0  58.00
# Segurança do Trabalho(60H)                          29.138014  0.0  59.75
# Seminário de Iniciação à Pesquisa(30H)              36.051261  0.0  60.00
# Seminário de Integração Acadêmica                   50.043352  0.0   0.00
# Seminário de Integração Acadêmica(10H)               0.000000  0.0   0.00
# Seminário de Orientação de Estágio Docente I        39.901327  0.0   0.00
# Seminário de Orientação de Estágio Docente III      40.349897  0.0   0.00
# Seminário de Orientação de Pesquisa I               40.485876  0.0   0.00
# Seminário de Orientação de Projeto Integrador I     42.499169  0.0   0.00
# Seminário de Orientação de Projeto Integrador II    44.372859  0.0   0.00
# Seminário de Orientação para a Prática Profissi...  39.969308  0.0   0.00
# Seminário de Orientação para a Prática Profissi...  36.331939  0.0  52.50
# Sociologia do Trabalho                              27.834107  0.0  42.25
# Teoria da Literatura I                              30.890448  0.0  13.00
# Teoria da Literatura II                             27.092776  0.0  60.00
#
#                                                       50%     75%    max
# descricao_historico
# Análise e Elaboração de Materiais de E/LE            64.5   86.00   98.0
# Atividades de Metodologia do Ensino de ELE I         70.0   96.50  100.0
# Controle Ambiental(60H)                              66.0   75.00   96.0
# Cultura Hispânica I                                  61.5   75.00  100.0
# Desenho Técnico(60H)                                 72.0   88.00  100.0
# Desenvolvimento de Projeto Integrador                80.0   95.00  100.0
# Desenvolvimento de Projetos Integradores I           77.0   88.00  100.0
# Desenvolvimento de Projetos Integradores II          82.5   93.00  100.0
# Dialetologia do Espanhol                             66.0   75.50  100.0
# Didática                                             75.0   86.00  100.0
# Direito Aplicado à Segurança e Saúde no Trabalh...   62.0   72.00  100.0
# EAD: Fundamentos e Práticas Aplicados a Educação     79.0   88.00  100.0
# Educação Inclusiva                                   68.0   83.00   98.0
# Ergonomia(60H)                                       71.0   81.00  100.0
# Estatística Aplicada à Segurança do Trabalho(30H)    64.0   80.00  100.0
# Extensão com TCC                                     74.0   86.00   97.0
# Filosofia da Linguagem                               60.0   71.00  100.0
# Filosofia, Ciência e Tecnologia                      75.0   90.00  100.0
# Fonética e Fonologia do Espanhol I                   63.0   77.00   98.0
# Fonética e Fonologia do Espanhol II                  70.0   83.00   95.0
# Fundamentos Históricos e Filosóficos da Educação     68.0   82.00  100.0
# Fundamentos Sociopolíticos e Econômicos da Educ...   69.0   82.25  100.0
# Fundamentos da Literatura                            62.0   76.00  100.0
# Fundamentos da Literatura Ocidental                  20.0   81.50   91.0
# Fundamentos e práticas na EAD(15H)                   65.0   79.00  100.0
# Gestão de Saúde e Segurança Ocupacional(60H)         60.0   83.00  100.0
# Gestão organizacional(30H)                           68.0   79.00  100.0
# Higiene Ocupacional(60H)                             62.0   74.00  100.0
# História da Língua Espanhola                         42.5   65.25  100.0
# Informática                                          75.0   83.00  100.0
# ...                                                   ...     ...    ...
# Língua Portuguesa                                    65.0   77.00  100.0
# Metodologia da Educação a Distância                  67.0   80.50  100.0
# Metodologia do Ensino de Espanhol como LE            62.0   81.50  100.0
# Metodologia do Trabalho Científico                   66.0   78.00  100.0
# Morfossintaxe I                                      62.5   76.00  100.0
# Morfossintaxe II                                     67.0   76.00   99.0
# Organização e Gestão da Educação Brasileira          60.0   72.00  100.0
# Prevenção e Combate à Incêndio (Sinistro)            74.0   84.00  100.0
# Prevenção e Combate à Sinistro(60H)                  67.0   76.00   94.0
# Prevenção e Controle de Perdas(90H)                  69.0   81.00  100.0
# Primeiros Socorros(60H)                              70.0   81.00  100.0
# Psicologia Geral(30H)                                73.0   87.00  100.0
# Psicologia da Educação                               72.0   82.00  100.0
# Psicologia do Trabalho(60H)                          61.0   75.00  100.0
# Qualidade de Vida e Trabalho                         70.0   80.00  100.0
# Saúde Ocupacional(30H)                               68.0   78.00  100.0
# Segurança do Trabalho(60H)                           70.0   79.00  100.0
# Seminário de Iniciação à Pesquisa(30H)               80.0   95.00  100.0
# Seminário de Integração Acadêmica                   100.0  100.00  100.0
# Seminário de Integração Acadêmica(10H)                0.0    0.00    0.0
# Seminário de Orientação de Estágio Docente I         74.0   89.00  100.0
# Seminário de Orientação de Estágio Docente III       73.0   83.00  100.0
# Seminário de Orientação de Pesquisa I                 0.0   73.50  100.0
# Seminário de Orientação de Projeto Integrador I      75.0   88.00  100.0
# Seminário de Orientação de Projeto Integrador II     83.0  100.00  100.0
# Seminário de Orientação para a Prática Profissi...   68.0   90.00  100.0
# Seminário de Orientação para a Prática Profissi...   75.0   92.00  100.0
# Sociologia do Trabalho                               64.0   74.00  100.0
# Teoria da Literatura I                               60.0   72.00   90.0
# Teoria da Literatura II                              66.5   77.50   90.0
#
# [78 rows x 8 columns]

# %%
"""
é plotado o gráfico violiono (boxplot + histogram) por disciplina, a fim de verificar o formato da distribuição
"""

#gerando graficos
# %matplotlib inline

plt.close('all')

cnt = 0

#loop sobre cada disciplina
for index1, group1 in merged.groupby(['disciplina_id']):    
    fig = plt.figure()
    sns.plt.suptitle(group1.iloc[1]['descricao_historico'])
    sns.violinplot(merged[merged.disciplina_id == index1]['media_final'])
    
    cnt += 1
    if cnt == 3:
        break

# %%
"""
é realizado a clusterização por disciplina em dois grupos (alunos aprovado e reprovados). é criado dentro do frame um novo
atributo chamado 'classe', o qual identifica a qual grupo aquele aluno pertence (0 reprovado, 1 aprovado). 

aqui a operação está limitada em 3, uma vez que a mesma gera gráficos e ficaria muito pesado o processamento. 
na cell seguinte a operação é realizada de forma completa sem gerar os gráficos
"""

plt.close('all')

#cria coluna 'classe' no frame merged inicializado com -1, a fim de controle
merged['classe'] = np.ones(merged.shape[0])*-1

#definir linha que divide os clusters (alunos bons e ruins)
cnt = 0

for index1, group1 in merged.groupby(['disciplina_id']):    
    
    #recuperando as notas apenas daquela disciplina    
    data = merged[merged.disciplina_id == index1]['media_final']
    
    #recuperando os clusters
    cluster = KMeans(n_clusters=2, init=np.array([[0], [10]]))
    cluster.fit(data.reshape(-1,1))
    #print(cluster.cluster_centers_)
        
    #atribuindo a classe
    merged.loc[merged.disciplina_id == index1, 'classe'] = cluster.predict(data.reshape(-1,1))
    
    
    #figura mostrando a clusterizacao
    fig = plt.figure()
    sns.distplot( merged[(merged.disciplina_id == index1) & (merged.classe == 0)]['media_final'] )
    sns.distplot( merged[(merged.disciplina_id == index1) & (merged.classe == 1)]['media_final'] )
    plt.plot(cluster.cluster_centers_, [0, 0], "o")
    
    #figura mostrando o ajuste dos dados aos clusters
    fig = plt.figure()
    stats.probplot(merged[(merged.disciplina_id == index1) & (merged.classe == 0)]['media_final'], plot=plt)
    stats.probplot(merged[(merged.disciplina_id == index1) & (merged.classe == 1)]['media_final'], plot=plt)
    
    #gerando kde para confirmar a clusterização
    
    #break
    
    cnt += 1
    if cnt == 3:
        break
# Out:
# C:\Users\Thiago\Anaconda3\lib\site-packages\ipykernel\__main__.py:16: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\Thiago\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:889: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\Users\Thiago\Anaconda3\lib\site-packages\ipykernel\__main__.py:20: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\Thiago\Anaconda3\lib\site-packages\statsmodels\nonparametric\kdetools.py:20: VisibleDeprecationWarning: using a non-integer number instead of an integer will result in an error in the future
#   y = X[:m/2+1] + np.r_[0,X[m/2+1:],0]*1j

# %%
"""
é realizado a clusterização por disciplina em dois grupos (alunos aprovado e reprovados). é criado dentro do frame um novo
atributo chamado 'classe', o qual identifica a qual grupo aquele aluno pertence (0 reprovado, 1 aprovado). 
"""

#criar coluna classe no merged
merged['classe'] = np.ones(merged.shape[0])*-1

#loop que para cada disciplina divide os clusters entre alunos aprovados e reprovados
for index1, group1 in merged.groupby(['disciplina_id']):    
    merged.loc[merged.disciplina_id == index1, 'classe'] = cluster.predict(data.reshape(-1,1))
    #recuperando as notas apenas daquela disciplina    
    data = merged[merged.disciplina_id == index1]['media_final']
    
    #recuperando os clusters
    cluster = KMeans(n_clusters=2, init=np.array([[0], [10]]))
    cluster.fit(data.reshape(-1,1))
    #print(cluster.cluster_centers_)
        
    #atribuindo a classe
    merged.loc[merged.disciplina_id == index1, 'classe'] = cluster.predict(data.reshape(-1,1))
# Out:
# C:\Users\Thiago\Anaconda3\lib\site-packages\ipykernel\__main__.py:14: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead
# C:\Users\Thiago\Anaconda3\lib\site-packages\sklearn\cluster\k_means_.py:889: RuntimeWarning: Explicit initial center position passed: performing only one init in k-means instead of n_init=10
#   return_n_iter=True)
# C:\Users\Thiago\Anaconda3\lib\site-packages\ipykernel\__main__.py:18: FutureWarning: reshape is deprecated and will raise in a subsequent release. Please use .values.reshape(...) instead

# %%
merged.groupby(['descricao_historico', 'classe'])['media_final'].describe().unstack()
# Out:
#                                                             count        mean  \
# descricao_historico                                classe
# Análise e Elaboração de Materiais de E/LE          0.0       28.0    9.000000
#                                                    1.0       40.0   80.350000
# Atividades de Metodologia do Ensino de ELE I       0.0       22.0    8.000000
#                                                    1.0       57.0   81.842105
# Controle Ambiental(60H)                            0.0       93.0    9.247312
#                                                    1.0      271.0   71.546125
# Cultura Hispânica I                                0.0       41.0    7.170732
#                                                    1.0       81.0   73.086420
# Desenho Técnico(60H)                               0.0      446.0    3.316143
#                                                    1.0      923.0   81.250271
# Desenvolvimento de Projeto Integrador              0.0      186.0    0.516129
#                                                    1.0      638.0   85.913793
# Desenvolvimento de Projetos Integradores I         0.0       57.0    0.000000
#                                                    1.0      109.0   84.871560
# Desenvolvimento de Projetos Integradores II        0.0       32.0    0.000000
#                                                    1.0       58.0   90.086207
# Dialetologia do Espanhol                           0.0       27.0   14.592593
#                                                    1.0       73.0   72.383562
# Didática                                           0.0       31.0    5.322581
#                                                    1.0      133.0   78.669173
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0      235.0   11.336170
#                                                    1.0      610.0   67.413115
# EAD: Fundamentos e Práticas Aplicados a Educação   0.0        7.0   13.428571
#                                                    1.0      138.0   79.123188
# Educação Inclusiva                                 0.0       46.0    6.000000
#                                                    1.0       90.0   77.233333
# Ergonomia(60H)                                     0.0      179.0    6.614525
#                                                    1.0      572.0   76.440559
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0      490.0    4.008163
#                                                    1.0      911.0   75.772777
# ...                                                           ...         ...
# Qualidade de Vida e Trabalho                       1.0      291.0   74.127148
# Saúde Ocupacional(30H)                             0.0      213.0    7.356808
#                                                    1.0      868.0   72.355991
# Segurança do Trabalho(60H)                         0.0      163.0    9.950920
#                                                    1.0      581.0   74.538726
# Seminário de Iniciação à Pesquisa(30H)             0.0      235.0    7.029787
#                                                    1.0      748.0   85.596257
# Seminário de Integração Acadêmica                  0.0      129.0    0.000000
#                                                    1.0      141.0  100.000000
# Seminário de Integração Acadêmica(10H)             0.0     1111.0    0.000000
# Seminário de Orientação de Estágio Docente I       0.0       29.0    5.206897
#                                                    1.0       48.0   83.895833
# Seminário de Orientação de Estágio Docente III     0.0       24.0    0.000000
#                                                    1.0       39.0   81.051282
# Seminário de Orientação de Pesquisa I              0.0       47.0    0.000000
#                                                    1.0       37.0   78.594595
# Seminário de Orientação de Projeto Integrador I    0.0       57.0    0.000000
#                                                    1.0       85.0   85.082353
# Seminário de Orientação de Projeto Integrador II   0.0       37.0    0.000000
#                                                    1.0       70.0   91.785714
# Seminário de Orientação para a Prática Profissi... 0.0      252.0    0.714286
#                                                    1.0      520.0   81.592308
# Seminário de Orientação para a Prática Profissi... 0.0       84.0    3.035714
#                                                    1.0      275.0   82.512727
# Sociologia do Trabalho                             0.0      256.0   10.378906
#                                                    1.0      814.0   69.255528
# Teoria da Literatura I                             0.0       59.0    8.949153
#                                                    1.0      103.0   68.699029
# Teoria da Literatura II                            0.0       12.0    2.833333
#                                                    1.0       62.0   70.096774
#
#                                                                  std    min  \
# descricao_historico                                classe
# Análise e Elaboração de Materiais de E/LE          0.0     11.620544    0.0
#                                                    1.0     12.745135   56.0
# Atividades de Metodologia do Ensino de ELE I       0.0     10.910895    0.0
#                                                    1.0     16.038781   60.0
# Controle Ambiental(60H)                            0.0     12.861855    0.0
#                                                    1.0     10.654711   41.0
# Cultura Hispânica I                                0.0     12.126216    0.0
#                                                    1.0     13.401677   41.0
# Desenho Técnico(60H)                               0.0      9.001176    0.0
#                                                    1.0     12.963790   43.0
# Desenvolvimento de Projeto Integrador              0.0      3.490877    0.0
#                                                    1.0     13.345562   60.0
# Desenvolvimento de Projetos Integradores I         0.0      0.000000    0.0
#                                                    1.0      9.769663   60.0
# Desenvolvimento de Projetos Integradores II        0.0      0.000000    0.0
#                                                    1.0      8.174167   70.0
# Dialetologia do Espanhol                           0.0     12.223116    0.0
#                                                    1.0     11.613725   49.0
# Didática                                           0.0      8.125627    0.0
#                                                    1.0     11.989719   45.0
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0     13.560003    0.0
#                                                    1.0     12.266733   35.0
# EAD: Fundamentos e Práticas Aplicados a Educação   0.0     14.627111    0.0
#                                                    1.0     10.731258   52.0
# Educação Inclusiva                                 0.0      9.531235    0.0
#                                                    1.0     11.633978   50.0
# Ergonomia(60H)                                     0.0     11.095703    0.0
#                                                    1.0     11.407051   43.0
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0      9.056285    0.0
#                                                    1.0     13.597025   40.0
# ...                                                              ...    ...
# Qualidade de Vida e Trabalho                       1.0     11.461223   45.0
# Saúde Ocupacional(30H)                             0.0     11.472461    0.0
#                                                    1.0     10.950923   41.0
# Segurança do Trabalho(60H)                         0.0     12.854746    0.0
#                                                    1.0     11.223312   44.0
# Seminário de Iniciação à Pesquisa(30H)             0.0     12.912392    0.0
#                                                    1.0     13.367630   50.0
# Seminário de Integração Acadêmica                  0.0      0.000000    0.0
#                                                    1.0      0.000000  100.0
# Seminário de Integração Acadêmica(10H)             0.0      0.000000    0.0
# Seminário de Orientação de Estágio Docente I       0.0     10.431338    0.0
#                                                    1.0     11.314159   60.0
# Seminário de Orientação de Estágio Docente III     0.0      0.000000    0.0
#                                                    1.0      9.377882   60.0
# Seminário de Orientação de Pesquisa I              0.0      0.000000    0.0
#                                                    1.0     15.059990   60.0
# Seminário de Orientação de Projeto Integrador I    0.0      0.000000    0.0
#                                                    1.0      9.560847   60.0
# Seminário de Orientação de Projeto Integrador II   0.0      0.000000    0.0
#                                                    1.0      8.328218   70.0
# Seminário de Orientação para a Prática Profissi... 0.0      4.582762    0.0
#                                                    1.0     14.957716   60.0
# Seminário de Orientação para a Prática Profissi... 0.0      8.794092    0.0
#                                                    1.0     14.760955   41.0
# Sociologia do Trabalho                             0.0     14.084931    0.0
#                                                    1.0     11.228853   40.0
# Teoria da Literatura I                             0.0     11.477750    0.0
#                                                    1.0     10.877063   41.0
# Teoria da Literatura II                            0.0      5.078177    0.0
#                                                    1.0     11.316186   44.0
#
#                                                               25%    50%  \
# descricao_historico                                classe
# Análise e Elaboração de Materiais de E/LE          0.0       0.00    0.0
#                                                    1.0      70.50   83.0
# Atividades de Metodologia do Ensino de ELE I       0.0       0.00    0.0
#                                                    1.0      66.00   80.0
# Controle Ambiental(60H)                            0.0       0.00    0.0
#                                                    1.0      63.00   72.0
# Cultura Hispânica I                                0.0       0.00    0.0
#                                                    1.0      62.00   70.0
# Desenho Técnico(60H)                               0.0       0.00    0.0
#                                                    1.0      72.00   83.0
# Desenvolvimento de Projeto Integrador              0.0       0.00    0.0
#                                                    1.0      80.00   90.0
# Desenvolvimento de Projetos Integradores I         0.0       0.00    0.0
#                                                    1.0      77.00   87.0
# Desenvolvimento de Projetos Integradores II        0.0       0.00    0.0
#                                                    1.0      83.00   92.0
# Dialetologia do Espanhol                           0.0       0.00   14.0
#                                                    1.0      64.00   71.0
# Didática                                           0.0       0.00    0.0
#                                                    1.0      69.00   79.0
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0       0.00    0.0
#                                                    1.0      60.00   66.0
# EAD: Fundamentos e Práticas Aplicados a Educação   0.0       0.00   12.0
#                                                    1.0      71.25   79.5
# Educação Inclusiva                                 0.0       0.00    0.0
#                                                    1.0      68.00   79.5
# Ergonomia(60H)                                     0.0       0.00    0.0
#                                                    1.0      68.00   76.0
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0       0.00    0.0
#                                                    1.0      65.00   75.0
# ...                                                           ...    ...
# Qualidade de Vida e Trabalho                       1.0      65.00   73.0
# Saúde Ocupacional(30H)                             0.0       0.00    0.0
#                                                    1.0      64.00   72.0
# Segurança do Trabalho(60H)                         0.0       0.00    0.0
#                                                    1.0      67.00   74.0
# Seminário de Iniciação à Pesquisa(30H)             0.0       0.00    0.0
#                                                    1.0      75.00   89.0
# Seminário de Integração Acadêmica                  0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Seminário de Integração Acadêmica(10H)             0.0       0.00    0.0
# Seminário de Orientação de Estágio Docente I       0.0       0.00    0.0
#                                                    1.0      75.75   88.0
# Seminário de Orientação de Estágio Docente III     0.0       0.00    0.0
#                                                    1.0      74.00   80.0
# Seminário de Orientação de Pesquisa I              0.0       0.00    0.0
#                                                    1.0      67.00   75.0
# Seminário de Orientação de Projeto Integrador I    0.0       0.00    0.0
#                                                    1.0      77.00   87.0
# Seminário de Orientação de Projeto Integrador II   0.0       0.00    0.0
#                                                    1.0      83.50   93.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00    0.0
#                                                    1.0      68.00   80.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00    0.0
#                                                    1.0      70.00   85.0
# Sociologia do Trabalho                             0.0       0.00    0.0
#                                                    1.0      62.00   68.0
# Teoria da Literatura I                             0.0       0.00    0.0
#                                                    1.0      61.00   68.0
# Teoria da Literatura II                            0.0       0.00    0.0
#                                                    1.0      63.00   68.0
#
#                                                               75%    max
# descricao_historico                                classe
# Análise e Elaboração de Materiais de E/LE          0.0      19.25   32.0
#                                                    1.0      90.00   98.0
# Atividades de Metodologia do Ensino de ELE I       0.0      16.75   32.0
#                                                    1.0     100.00  100.0
# Controle Ambiental(60H)                            0.0      16.00   36.0
#                                                    1.0      78.00   96.0
# Cultura Hispânica I                                0.0      13.00   34.0
#                                                    1.0      86.00  100.0
# Desenho Técnico(60H)                               0.0       0.00   42.0
#                                                    1.0      91.00  100.0
# Desenvolvimento de Projeto Integrador              0.0       0.00   24.0
#                                                    1.0     100.00  100.0
# Desenvolvimento de Projetos Integradores I         0.0       0.00    0.0
#                                                    1.0      92.00  100.0
# Desenvolvimento de Projetos Integradores II        0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Dialetologia do Espanhol                           0.0      20.00   41.0
#                                                    1.0      83.00  100.0
# Didática                                           0.0      10.00   24.0
#                                                    1.0      88.00  100.0
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0      24.00   40.0
#                                                    1.0      76.00  100.0
# EAD: Fundamentos e Práticas Aplicados a Educação   0.0      24.50   33.0
#                                                    1.0      88.00  100.0
# Educação Inclusiva                                 0.0       9.50   32.0
#                                                    1.0      86.00   98.0
# Ergonomia(60H)                                     0.0      12.50   42.0
#                                                    1.0      84.00  100.0
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0       0.00   39.0
#                                                    1.0      85.50  100.0
# ...                                                           ...    ...
# Qualidade de Vida e Trabalho                       1.0      83.00  100.0
# Saúde Ocupacional(30H)                             0.0      15.00   39.0
#                                                    1.0      81.00  100.0
# Segurança do Trabalho(60H)                         0.0      20.50   42.0
#                                                    1.0      82.00  100.0
# Seminário de Iniciação à Pesquisa(30H)             0.0      12.00   45.0
#                                                    1.0      98.00  100.0
# Seminário de Integração Acadêmica                  0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Seminário de Integração Acadêmica(10H)             0.0       0.00    0.0
# Seminário de Orientação de Estágio Docente I       0.0       8.00   40.0
#                                                    1.0      92.25  100.0
# Seminário de Orientação de Estágio Docente III     0.0       0.00    0.0
#                                                    1.0      88.50  100.0
# Seminário de Orientação de Pesquisa I              0.0       0.00    0.0
#                                                    1.0      95.00  100.0
# Seminário de Orientação de Projeto Integrador I    0.0       0.00    0.0
#                                                    1.0      91.00  100.0
# Seminário de Orientação de Projeto Integrador II   0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00   30.0
#                                                    1.0     100.00  100.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00   36.0
#                                                    1.0      97.00  100.0
# Sociologia do Trabalho                             0.0      22.50   39.0
#                                                    1.0      77.00  100.0
# Teoria da Literatura I                             0.0      16.50   37.0
#                                                    1.0      77.50   90.0
# Teoria da Literatura II                            0.0       3.00   14.0
#                                                    1.0      79.00   90.0
#
# [155 rows x 8 columns]

# %%
#filtra disciplinas com registros maiores que 30 por classe (teorema do limite central pg. 55 Laura Igual)
#print(merged.shape)
merged = merged.groupby(['descricao_historico', 'classe']).filter(lambda x: len(x) > 30)
#print(merged.shape)

#filtra disciplina que tem duas classes
merged = merged.groupby(['descricao_historico']).filter(lambda x: x["classe"].std() > 0)
merged.groupby(['descricao_historico', 'classe'])['media_final'].describe().unstack()
# Out:
#                                                            count        mean  \
# descricao_historico                                classe
# Controle Ambiental(60H)                            0.0      93.0    9.247312
#                                                    1.0     271.0   71.546125
# Cultura Hispânica I                                0.0      41.0    7.170732
#                                                    1.0      81.0   73.086420
# Desenho Técnico(60H)                               0.0     446.0    3.316143
#                                                    1.0     923.0   81.250271
# Desenvolvimento de Projeto Integrador              0.0     186.0    0.516129
#                                                    1.0     638.0   85.913793
# Desenvolvimento de Projetos Integradores I         0.0      57.0    0.000000
#                                                    1.0     109.0   84.871560
# Desenvolvimento de Projetos Integradores II        0.0      32.0    0.000000
#                                                    1.0      58.0   90.086207
# Didática                                           0.0      31.0    5.322581
#                                                    1.0     133.0   78.669173
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0     235.0   11.336170
#                                                    1.0     610.0   67.413115
# Educação Inclusiva                                 0.0      46.0    6.000000
#                                                    1.0      90.0   77.233333
# Ergonomia(60H)                                     0.0     179.0    6.614525
#                                                    1.0     572.0   76.440559
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0     490.0    4.008163
#                                                    1.0     911.0   75.772777
# Filosofia da Linguagem                             0.0      44.0   18.250000
#                                                    1.0      61.0   71.573770
# Filosofia, Ciência e Tecnologia                    0.0     188.0    7.723404
#                                                    1.0     796.0   79.753769
# Fonética e Fonologia do Espanhol I                 0.0      72.0   25.611111
#                                                    1.0     164.0   72.054878
# Fundamentos Históricos e Filosóficos da Educação   0.0      91.0    8.945055
#                                                    1.0     204.0   76.220588
# ...                                                          ...         ...
# Psicologia Geral(30H)                              0.0     462.0    3.720779
#                                                    1.0     901.0   81.801332
# Psicologia da Educação                             0.0      36.0    9.555556
#                                                    1.0     155.0   75.812903
# Psicologia do Trabalho(60H)                        0.0     358.0   10.072626
#                                                    1.0     777.0   70.555985
# Qualidade de Vida e Trabalho                       0.0      65.0   13.676923
#                                                    1.0     291.0   74.127148
# Saúde Ocupacional(30H)                             0.0     213.0    7.356808
#                                                    1.0     868.0   72.355991
# Segurança do Trabalho(60H)                         0.0     163.0    9.950920
#                                                    1.0     581.0   74.538726
# Seminário de Iniciação à Pesquisa(30H)             0.0     235.0    7.029787
#                                                    1.0     748.0   85.596257
# Seminário de Integração Acadêmica                  0.0     129.0    0.000000
#                                                    1.0     141.0  100.000000
# Seminário de Orientação de Pesquisa I              0.0      47.0    0.000000
#                                                    1.0      37.0   78.594595
# Seminário de Orientação de Projeto Integrador I    0.0      57.0    0.000000
#                                                    1.0      85.0   85.082353
# Seminário de Orientação de Projeto Integrador II   0.0      37.0    0.000000
#                                                    1.0      70.0   91.785714
# Seminário de Orientação para a Prática Profissi... 0.0     252.0    0.714286
#                                                    1.0     520.0   81.592308
# Seminário de Orientação para a Prática Profissi... 0.0      84.0    3.035714
#                                                    1.0     275.0   82.512727
# Sociologia do Trabalho                             0.0     256.0   10.378906
#                                                    1.0     814.0   69.255528
# Teoria da Literatura I                             0.0      59.0    8.949153
#                                                    1.0     103.0   68.699029
#
#                                                                  std    min  \
# descricao_historico                                classe
# Controle Ambiental(60H)                            0.0     12.861855    0.0
#                                                    1.0     10.654711   41.0
# Cultura Hispânica I                                0.0     12.126216    0.0
#                                                    1.0     13.401677   41.0
# Desenho Técnico(60H)                               0.0      9.001176    0.0
#                                                    1.0     12.963790   43.0
# Desenvolvimento de Projeto Integrador              0.0      3.490877    0.0
#                                                    1.0     13.345562   60.0
# Desenvolvimento de Projetos Integradores I         0.0      0.000000    0.0
#                                                    1.0      9.769663   60.0
# Desenvolvimento de Projetos Integradores II        0.0      0.000000    0.0
#                                                    1.0      8.174167   70.0
# Didática                                           0.0      8.125627    0.0
#                                                    1.0     11.989719   45.0
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0     13.560003    0.0
#                                                    1.0     12.266733   35.0
# Educação Inclusiva                                 0.0      9.531235    0.0
#                                                    1.0     11.633978   50.0
# Ergonomia(60H)                                     0.0     11.095703    0.0
#                                                    1.0     11.407051   43.0
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0      9.056285    0.0
#                                                    1.0     13.597025   40.0
# Filosofia da Linguagem                             0.0     14.346420    0.0
#                                                    1.0     12.108481   49.0
# Filosofia, Ciência e Tecnologia                    0.0     12.624909    0.0
#                                                    1.0     12.176880   49.0
# Fonética e Fonologia do Espanhol I                 0.0     16.128494    0.0
#                                                    1.0     12.312024   49.0
# Fundamentos Históricos e Filosóficos da Educação   0.0     14.531470    0.0
#                                                    1.0     12.812224   44.0
# ...                                                              ...    ...
# Psicologia Geral(30H)                              0.0      9.661178    0.0
#                                                    1.0     11.962787   42.0
# Psicologia da Educação                             0.0     13.131085    0.0
#                                                    1.0     12.465426   43.0
# Psicologia do Trabalho(60H)                        0.0     13.318771    0.0
#                                                    1.0     13.037111   39.0
# Qualidade de Vida e Trabalho                       0.0     14.821972    0.0
#                                                    1.0     11.461223   45.0
# Saúde Ocupacional(30H)                             0.0     11.472461    0.0
#                                                    1.0     10.950923   41.0
# Segurança do Trabalho(60H)                         0.0     12.854746    0.0
#                                                    1.0     11.223312   44.0
# Seminário de Iniciação à Pesquisa(30H)             0.0     12.912392    0.0
#                                                    1.0     13.367630   50.0
# Seminário de Integração Acadêmica                  0.0      0.000000    0.0
#                                                    1.0      0.000000  100.0
# Seminário de Orientação de Pesquisa I              0.0      0.000000    0.0
#                                                    1.0     15.059990   60.0
# Seminário de Orientação de Projeto Integrador I    0.0      0.000000    0.0
#                                                    1.0      9.560847   60.0
# Seminário de Orientação de Projeto Integrador II   0.0      0.000000    0.0
#                                                    1.0      8.328218   70.0
# Seminário de Orientação para a Prática Profissi... 0.0      4.582762    0.0
#                                                    1.0     14.957716   60.0
# Seminário de Orientação para a Prática Profissi... 0.0      8.794092    0.0
#                                                    1.0     14.760955   41.0
# Sociologia do Trabalho                             0.0     14.084931    0.0
#                                                    1.0     11.228853   40.0
# Teoria da Literatura I                             0.0     11.477750    0.0
#                                                    1.0     10.877063   41.0
#
#                                                               25%    50%  \
# descricao_historico                                classe
# Controle Ambiental(60H)                            0.0       0.00    0.0
#                                                    1.0      63.00   72.0
# Cultura Hispânica I                                0.0       0.00    0.0
#                                                    1.0      62.00   70.0
# Desenho Técnico(60H)                               0.0       0.00    0.0
#                                                    1.0      72.00   83.0
# Desenvolvimento de Projeto Integrador              0.0       0.00    0.0
#                                                    1.0      80.00   90.0
# Desenvolvimento de Projetos Integradores I         0.0       0.00    0.0
#                                                    1.0      77.00   87.0
# Desenvolvimento de Projetos Integradores II        0.0       0.00    0.0
#                                                    1.0      83.00   92.0
# Didática                                           0.0       0.00    0.0
#                                                    1.0      69.00   79.0
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0       0.00    0.0
#                                                    1.0      60.00   66.0
# Educação Inclusiva                                 0.0       0.00    0.0
#                                                    1.0      68.00   79.5
# Ergonomia(60H)                                     0.0       0.00    0.0
#                                                    1.0      68.00   76.0
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0       0.00    0.0
#                                                    1.0      65.00   75.0
# Filosofia da Linguagem                             0.0       1.50   18.0
#                                                    1.0      62.00   70.0
# Filosofia, Ciência e Tecnologia                    0.0       0.00    0.0
#                                                    1.0      70.00   80.0
# Fonética e Fonologia do Espanhol I                 0.0      13.00   29.0
#                                                    1.0      62.00   70.5
# Fundamentos Históricos e Filosóficos da Educação   0.0       0.00    0.0
#                                                    1.0      66.75   77.0
# ...                                                           ...    ...
# Psicologia Geral(30H)                              0.0       0.00    0.0
#                                                    1.0      73.00   84.0
# Psicologia da Educação                             0.0       0.00    0.0
#                                                    1.0      66.00   77.0
# Psicologia do Trabalho(60H)                        0.0       0.00    0.0
#                                                    1.0      61.00   69.0
# Qualidade de Vida e Trabalho                       0.0       0.00   10.0
#                                                    1.0      65.00   73.0
# Saúde Ocupacional(30H)                             0.0       0.00    0.0
#                                                    1.0      64.00   72.0
# Segurança do Trabalho(60H)                         0.0       0.00    0.0
#                                                    1.0      67.00   74.0
# Seminário de Iniciação à Pesquisa(30H)             0.0       0.00    0.0
#                                                    1.0      75.00   89.0
# Seminário de Integração Acadêmica                  0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Seminário de Orientação de Pesquisa I              0.0       0.00    0.0
#                                                    1.0      67.00   75.0
# Seminário de Orientação de Projeto Integrador I    0.0       0.00    0.0
#                                                    1.0      77.00   87.0
# Seminário de Orientação de Projeto Integrador II   0.0       0.00    0.0
#                                                    1.0      83.50   93.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00    0.0
#                                                    1.0      68.00   80.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00    0.0
#                                                    1.0      70.00   85.0
# Sociologia do Trabalho                             0.0       0.00    0.0
#                                                    1.0      62.00   68.0
# Teoria da Literatura I                             0.0       0.00    0.0
#                                                    1.0      61.00   68.0
#
#                                                               75%    max
# descricao_historico                                classe
# Controle Ambiental(60H)                            0.0      16.00   36.0
#                                                    1.0      78.00   96.0
# Cultura Hispânica I                                0.0      13.00   34.0
#                                                    1.0      86.00  100.0
# Desenho Técnico(60H)                               0.0       0.00   42.0
#                                                    1.0      91.00  100.0
# Desenvolvimento de Projeto Integrador              0.0       0.00   24.0
#                                                    1.0     100.00  100.0
# Desenvolvimento de Projetos Integradores I         0.0       0.00    0.0
#                                                    1.0      92.00  100.0
# Desenvolvimento de Projetos Integradores II        0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Didática                                           0.0      10.00   24.0
#                                                    1.0      88.00  100.0
# Direito Aplicado à Segurança e Saúde no Trabalh... 0.0      24.00   40.0
#                                                    1.0      76.00  100.0
# Educação Inclusiva                                 0.0       9.50   32.0
#                                                    1.0      86.00   98.0
# Ergonomia(60H)                                     0.0      12.50   42.0
#                                                    1.0      84.00  100.0
# Estatística Aplicada à Segurança do Trabalho(30H)  0.0       0.00   39.0
#                                                    1.0      85.50  100.0
# Filosofia da Linguagem                             0.0      28.50   43.0
#                                                    1.0      80.00  100.0
# Filosofia, Ciência e Tecnologia                    0.0      15.25   42.0
#                                                    1.0      90.00  100.0
# Fonética e Fonologia do Espanhol I                 0.0      40.25   48.0
#                                                    1.0      82.25   98.0
# Fundamentos Históricos e Filosóficos da Educação   0.0      15.00   41.0
#                                                    1.0      86.00  100.0
# ...                                                           ...    ...
# Psicologia Geral(30H)                              0.0       0.00   40.0
#                                                    1.0      91.00  100.0
# Psicologia da Educação                             0.0      17.25   37.0
#                                                    1.0      85.00  100.0
# Psicologia do Trabalho(60H)                        0.0      21.00   39.0
#                                                    1.0      80.00  100.0
# Qualidade de Vida e Trabalho                       0.0      27.00   42.0
#                                                    1.0      83.00  100.0
# Saúde Ocupacional(30H)                             0.0      15.00   39.0
#                                                    1.0      81.00  100.0
# Segurança do Trabalho(60H)                         0.0      20.50   42.0
#                                                    1.0      82.00  100.0
# Seminário de Iniciação à Pesquisa(30H)             0.0      12.00   45.0
#                                                    1.0      98.00  100.0
# Seminário de Integração Acadêmica                  0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Seminário de Orientação de Pesquisa I              0.0       0.00    0.0
#                                                    1.0      95.00  100.0
# Seminário de Orientação de Projeto Integrador I    0.0       0.00    0.0
#                                                    1.0      91.00  100.0
# Seminário de Orientação de Projeto Integrador II   0.0       0.00    0.0
#                                                    1.0     100.00  100.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00   30.0
#                                                    1.0     100.00  100.0
# Seminário de Orientação para a Prática Profissi... 0.0       0.00   36.0
#                                                    1.0      97.00  100.0
# Sociologia do Trabalho                             0.0      22.50   39.0
#                                                    1.0      77.00  100.0
# Teoria da Literatura I                             0.0      16.50   37.0
#                                                    1.0      77.50   90.0
#
# [120 rows x 8 columns]

# %%
#test de normalidade
#stats.normaltest

#test se duas amostras são da mesma distribuição
df_ind0 = pd.DataFrame()
df_ind1 = pd.DataFrame()
#stats.ttest_ind(a,b)

#test
for index1, group1 in merged.groupby(['disciplina_id']):   
    #print(merged[(merged.disciplina_id == index1) & (merged.classe == 0)]['media_final'].shape)
    #print(stats.normaltest(merged[(merged.disciplina_id == index1) & (merged.classe == 0)]['media_final']))
    #print(stats.normaltest(merged[(merged.disciplina_id == index1) & (merged.classe == 1)]['media_final']))
    
    arr_test0 = []
    arr_test1 = []
    
    for index2, group2 in merged.groupby(['disciplina_id']):
        mf10 = merged[(merged.disciplina_id == index1) & (merged.classe == 0)]['media_final']
        mf20 = merged[(merged.disciplina_id == index2) & (merged.classe == 0)]['media_final']
        
        mf11 = merged[(merged.disciplina_id == index1) & (merged.classe == 1)]['media_final']
        mf21 = merged[(merged.disciplina_id == index2) & (merged.classe == 1)]['media_final']
    
        arr_test0.append( stats.ttest_ind(mf10,mf20).pvalue )
        arr_test1.append( stats.ttest_ind(mf11,mf21).pvalue )
        
    #salvando os testes
    df_ind0[index1] = arr_test0
    df_ind1[index1] = arr_test1    
    #break
# Out:
# C:\Users\Thiago\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in greater
#   return (self.a < x) & (x < self.b)
# C:\Users\Thiago\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:875: RuntimeWarning: invalid value encountered in less
#   return (self.a < x) & (x < self.b)
# C:\Users\Thiago\Anaconda3\lib\site-packages\scipy\stats\_distn_infrastructure.py:1814: RuntimeWarning: invalid value encountered in less_equal
#   cond2 = cond0 & (x <= self.a)

# %%
#grafico de testes
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df_ind0)

# %%
def f(x):
    if x > 0.05:
        x = 1
    else:
        x = 0
    return x

df_ind0 = df_ind0.applymap(f)

#grafico de testes
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df_ind0)

# %%
merged.head
# Out:
# <bound method NDFrame.head of        disciplina_id  matricula_periodo_id  media_final  \
# 0         9204455505         1311175667413           85
# 1         9204455505         1402068770613          100
# 2         9204455505         1311242582581           88
# 3         9204455505         1311239794449           88
# 4         9204455505         1382936608829           63
# 5         9204455505         1312268615157           85
# 6         9204455505         1402302973701           73
# 7         9204455505         1402202600949           84
# 8         9204455505         1382429168805           88
# 9         9204455505         1382298126601           67
# 10        9204455505         1486621661645            0
# 11        9204455505         1382721922665           21
# 12        9204455505         1382699617609           34
# 13        9204455505         1382866905529           64
# 14        9204455505         1382758168381            0
# 15        9204455505         1382942185093           19
# 16        9204455505         1311200760601           94
# 17        9204455505         1312327165929           63
# 18        9204455505         1305236946253            0
# 19        9204455505         1354907517833           87
# 20        9204455505         1309332712161           74
# 21        9204455505         1382772109041           62
# 22        9204455505         1403147777697           98
# 23        9204455505         1382741439589           18
# 24        9204455505         1403128260773           87
# 25        9204455505         1486630026041            0
# 26        9204455505         1382733075193            6
# 27        9204455505         1309460966233           93
# 28        9204455505         1305724869353            0
# 29        9204455505         1406716586657            0
# ...              ...                   ...          ...
# 35729     6204425473         1003600097701           88
# 35730     6204425473         1290077872569           70
# 35731     6204425473         1290273041809            0
# 35732     6204425473         1003717199245           87
# 35733     6204425473         1290401295881            0
# 35734     6204425473          785938996857          100
# 35735     6204425473         1289974711685            0
# 35736     6204425473         1003703258585           82
# 35737     6204425473         1003725563641           75
# 35738     6204425473         1290604829517            0
# 35739     6204425473         1290409660277           88
# 35740     6204425473         1004146571573           75
# 35741     6204425473         1290613193913            0
# 35742     6204425473         1289843669481            0
# 35743     6204425473         1289932889705            0
# 35744     6204425473         1290487727973           81
# 35745     6204425473         1004163300365           87
# 35746     6204425473         1290041626853            0
# 35747     6204425473         1003825936393            0
# 35748     6204425473         1004166088497           77
# 35749     6204425473         1290373414561            0
# 35750     6204425473         1003719987377           87
# 35751     6204425473         1290518397425           81
# 35752     6204425473         1290206126641            0
# 35753     6204425473         1290507244897            0
# 35754     6204425473         1004302706965            0
# 35755     6204425473         1290537914349           99
# 35756     6204425473         1290515609293            0
# 35757     6204425473         1003594521437            0
# 35758     6204425473         1289740508597           92
#
#        percentual_frequencia professores  situacao_id  ch_hora_relogio  \
# 0                      100.0      [1073]    923703465               60
# 1                      100.0      [1073]    923703465               60
# 2                      100.0      [1073]    923703465               60
# 3                      100.0      [1073]    923703465               60
# 4                       85.0       [534]    923703465               60
# 5                      100.0      [1073]    923703465               60
# 6                      100.0      [1073]    923703465               60
# 7                      100.0      [1073]    923703465               60
# 8                      100.0      [1073]    923703465               60
# 9                       90.0       [534]    923703465               60
# 10                     100.0      [1073]    934855993               60
# 11                      85.0       [534]    926491597               60
# 12                      53.0      [1073]    926491597               60
# 13                      95.0       [534]    923703465               60
# 14                      95.0       [534]    934855993               60
# 15                      85.0       [534]    926491597               60
# 16                     100.0      [1073]    923703465               60
# 17                     100.0      [1073]    923703465               60
# 18                     100.0      [1073]    934855993               60
# 19                     100.0      [1073]    923703465               60
# 20                     100.0      [1073]    923703465               60
# 21                      95.0       [534]    923703465               60
# 22                     100.0      [1073]    923703465               60
# 23                      78.0       [534]    926491597               60
# 24                     100.0      [1073]    923703465               60
# 25                     100.0      [1073]    937644125               60
# 26                      65.0       [534]    926491597               60
# 27                     100.0      [1073]    923703465               60
# 28                       0.0      [1073]    926491597               60
# 29                      10.0       [534]    926491597               60
# ...                      ...         ...          ...              ...
# 35729                  100.0         NaN    923703465               30
# 35730                  100.0         NaN    923703465               30
# 35731                  100.0         NaN    926491597               30
# 35732                  100.0         NaN    923703465               30
# 35733                  100.0         NaN    926491597               30
# 35734                  100.0         NaN    923703465               30
# 35735                  100.0         NaN    926491597               30
# 35736                  100.0         NaN    923703465               30
# 35737                  100.0         NaN    923703465               30
# 35738                  100.0         NaN    926491597               30
# 35739                  100.0         NaN    923703465               30
# 35740                  100.0         NaN    923703465               30
# 35741                  100.0         NaN    926491597               30
# 35742                  100.0         NaN    926491597               30
# 35743                  100.0         NaN    926491597               30
# 35744                  100.0         NaN    923703465               30
# 35745                  100.0         NaN    923703465               30
# 35746                  100.0         NaN    926491597               30
# 35747                  100.0         NaN    926491597               30
# 35748                  100.0         NaN    923703465               30
# 35749                  100.0         NaN    926491597               30
# 35750                  100.0         NaN    923703465               30
# 35751                  100.0         NaN    923703465               30
# 35752                  100.0         NaN    926491597               30
# 35753                  100.0         NaN    926491597               30
# 35754                  100.0         NaN    926491597               30
# 35755                  100.0         NaN    923703465               30
# 35756                  100.0         NaN    926491597               30
# 35757                  100.0         NaN    926491597               30
# 35758                  100.0         NaN    923703465               30
#
#                                    descricao_historico          id  classe
# 0                           Introdução ao Direito(60H)  9204455505     1.0
# 1                           Introdução ao Direito(60H)  9204455505     1.0
# 2                           Introdução ao Direito(60H)  9204455505     1.0
# 3                           Introdução ao Direito(60H)  9204455505     1.0
# 4                           Introdução ao Direito(60H)  9204455505     1.0
# 5                           Introdução ao Direito(60H)  9204455505     1.0
# 6                           Introdução ao Direito(60H)  9204455505     1.0
# 7                           Introdução ao Direito(60H)  9204455505     1.0
# 8                           Introdução ao Direito(60H)  9204455505     1.0
# 9                           Introdução ao Direito(60H)  9204455505     1.0
# 10                          Introdução ao Direito(60H)  9204455505     0.0
# 11                          Introdução ao Direito(60H)  9204455505     0.0
# 12                          Introdução ao Direito(60H)  9204455505     0.0
# 13                          Introdução ao Direito(60H)  9204455505     1.0
# 14                          Introdução ao Direito(60H)  9204455505     0.0
# 15                          Introdução ao Direito(60H)  9204455505     0.0
# 16                          Introdução ao Direito(60H)  9204455505     1.0
# 17                          Introdução ao Direito(60H)  9204455505     1.0
# 18                          Introdução ao Direito(60H)  9204455505     0.0
# 19                          Introdução ao Direito(60H)  9204455505     1.0
# 20                          Introdução ao Direito(60H)  9204455505     1.0
# 21                          Introdução ao Direito(60H)  9204455505     1.0
# 22                          Introdução ao Direito(60H)  9204455505     1.0
# 23                          Introdução ao Direito(60H)  9204455505     0.0
# 24                          Introdução ao Direito(60H)  9204455505     1.0
# 25                          Introdução ao Direito(60H)  9204455505     0.0
# 26                          Introdução ao Direito(60H)  9204455505     0.0
# 27                          Introdução ao Direito(60H)  9204455505     1.0
# 28                          Introdução ao Direito(60H)  9204455505     0.0
# 29                          Introdução ao Direito(60H)  9204455505     0.0
# ...                                                ...         ...     ...
# 35729  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35730  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35731  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35732  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35733  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35734  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35735  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35736  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35737  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35738  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35739  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35740  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35741  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35742  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35743  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35744  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35745  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35746  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35747  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35748  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35749  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35750  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35751  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35752  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35753  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35754  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35755  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
# 35756  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35757  Seminário de Orientação de Projeto Integrador I  6204425473     0.0
# 35758  Seminário de Orientação de Projeto Integrador I  6204425473     1.0
#
# [31483 rows x 10 columns]>

# %%
#verificar se há diferença estatística entre as médias entre os cursos

merged_aluno = pd.merge(merged, df_MatriculaPeriodo, left_on="matricula_periodo_id", right_on="id", suffixes=["_M", "_MP"])
merged_aluno = pd.merge(merged_aluno, df_Caracterizacao, left_on="aluno_id", right_on="aluno_id", suffixes=["", "_CA"])
merged_aluno = pd.merge(merged_aluno, df_aluno, left_on="aluno_id", right_on="id", suffixes=["", "_AL"])
merged_aluno = pd.merge(merged_aluno, df_CursoCampus, left_on="curso_campus_id", right_on="id", suffixes=["", "_CU"])
merged_aluno = pd.merge(merged_aluno, df_Raca, left_on="raca_id", right_on="id", suffixes=["", "_RA"])
merged_aluno = pd.merge(merged_aluno, df_EstadoCivil, left_on="estado_civil_id", right_on="id", suffixes=["", "_EC"])
merged_aluno = pd.merge(merged_aluno, df_SituacaoMatricula, left_on="situacao_id", right_on="id", suffixes=["", "_SM"])

#filtrando usuários q tenham renda bruta maior que 2*s
merged_aluno = merged_aluno[merged_aluno.renda_bruta_familiar < (merged_aluno['renda_bruta_familiar'].median() +
                                                            2*merged_aluno['renda_bruta_familiar'].std()) ]
bins = [0, 1874, 3748, 9370, 18740, 20000]
group_names = ['E', 'D', 'C', 'B', 'A']
merged_aluno['categorias'] = pd.cut(merged_aluno['renda_bruta_familiar'], bins, labels=group_names)

print(merged_aluno.columns)

df = merged_aluno[[ 
                    'aluno_id', 'descricao_RA', 'categorias', 'cep', 'descricao_EC',
                    'media_final', 'percentual_frequencia', 'classe',
                    'descricao_historico', 
                    'descricao', 
                    'descricao_SM'
                 ]]

df.head
# Out:
# Index(['disciplina_id', 'matricula_periodo_id', 'media_final',
#        'percentual_frequencia', 'professores', 'situacao_id_M',
#        'ch_hora_relogio', 'descricao_historico', 'id_M', 'classe', 'aluno_id',
#        'ano_letivo__ano', 'id_MP', 'periodo_letivo', 'situacao_id_MP',
#        'aluno_exclusivo_rede_publica', 'companhia_domiciliar_id',
#        'ensino_fundamental_conclusao', 'ensino_medio_conclusao',
#        'escola_ensino_fundamental_id', 'escola_ensino_medio_id',
#        'estado_civil_id', 'ficou_tempo_sem_estudar',
#        'frequencia_acesso_internet_id', 'historico_caracterizacao_id', 'id',
#        'local_acesso_internet', 'mae_nivel_escolaridade_id',
#        'nome_escola_ensino_fundamental', 'nome_escola_ensino_medio',
#        'pai_nivel_escolaridade_id', 'possui_conhecimento_idiomas',
#        'possui_conhecimento_informatica', 'possui_necessidade_especial',
#        'qtd_filhos', 'qtd_pessoas_domicilio', 'quantidade_computadores',
#        'quantidade_netbooks', 'quantidade_notebooks', 'quantidade_smartphones',
#        'raca_id', 'razao_ausencia_educacional_id', 'renda_bruta_familiar',
#        'renda_per_capita', 'responsavel_financeir_trabalho_situacao_id',
#        'responsavel_financeiro_id',
#        'responsavel_financeiro_nivel_escolaridade_id', 'tempo_sem_estudar',
#        'tipo_area_residencial_id', 'tipo_imovel_residencial_id',
#        'tipo_servico_saude_id', 'trabalho_situacao_id', 'ano_letivo__ano_AL',
#        'cep', 'cidade__estado__nome', 'cidade__nome', 'curso_campus_id',
#        'id_AL', 'periodo_letivo_AL', 'pessoa_fisica__nascimento_data',
#        'situacao_id', 'descricao', 'id_CU', 'codigo_censup', 'codigo_siape',
#        'descricao_RA', 'id_RA', 'inativo_siape', 'descricao_EC', 'id_EC',
#        'descricao_SM', 'id_SM', 'categorias'],
#       dtype='object')
# <bound method NDFrame.head of            aluno_id   descricao_RA categorias        cep   descricao_EC  \
# 0      471409825937  Não declarado          D  59082-420      Casado(a)
# 1      471409825937  Não declarado          D  59082-420      Casado(a)
# 2      471409825937  Não declarado          D  59082-420      Casado(a)
# 3      471409825937  Não declarado          D  59082-420      Casado(a)
# 4      471409825937  Não declarado          D  59082-420      Casado(a)
# 5      471409825937  Não declarado          D  59082-420      Casado(a)
# 6      471409825937  Não declarado          D  59082-420      Casado(a)
# 7      471409825937  Não declarado          D  59082-420      Casado(a)
# 8      471409825937  Não declarado          D  59082-420      Casado(a)
# 9      471409825937  Não declarado          D  59082-420      Casado(a)
# 10     471409825937  Não declarado          D  59082-420      Casado(a)
# 11     471409825937  Não declarado          D  59082-420      Casado(a)
# 12     471409825937  Não declarado          D  59082-420      Casado(a)
# 13     471409825937  Não declarado          D  59082-420      Casado(a)
# 14     471409825937  Não declarado          D  59082-420      Casado(a)
# 15     471409825937  Não declarado          D  59082-420      Casado(a)
# 16     471409825937  Não declarado          D  59082-420      Casado(a)
# 17     471409825937  Não declarado          D  59082-420      Casado(a)
# 18     471409825937  Não declarado          D  59082-420      Casado(a)
# 19     471409825937  Não declarado          D  59082-420      Casado(a)
# 20     471409825937  Não declarado          D  59082-420      Casado(a)
# 21     471409825937  Não declarado          D  59082-420      Casado(a)
# 22     470999970533  Não declarado          E  59615-000      Casado(a)
# 23     470999970533  Não declarado          E  59615-000      Casado(a)
# 24     470999970533  Não declarado          E  59615-000      Casado(a)
# 25     470999970533  Não declarado          E  59615-000      Casado(a)
# 26     470999970533  Não declarado          E  59615-000      Casado(a)
# 27     470999970533  Não declarado          E  59615-000      Casado(a)
# 28     470999970533  Não declarado          E  59615-000      Casado(a)
# 29     470999970533  Não declarado          E  59615-000      Casado(a)
# ...             ...            ...        ...        ...            ...
# 34985  346992223569         Branca          E  59380-000  Divorciado(a)
# 34986  346992223569         Branca          E  59380-000  Divorciado(a)
# 34987  346992223569         Branca          E  59380-000  Divorciado(a)
# 34988  346992223569         Branca          E  59380-000  Divorciado(a)
# 34989  346992223569         Branca          E  59380-000  Divorciado(a)
# 34990  346992223569         Branca          E  59380-000  Divorciado(a)
# 34991  346992223569         Branca          E  59380-000  Divorciado(a)
# 34992  346992223569         Branca          E  59380-000  Divorciado(a)
# 34993  346992223569         Branca          E  59380-000  Divorciado(a)
# 34994  346992223569         Branca          E  59380-000  Divorciado(a)
# 34995  346992223569         Branca          E  59380-000  Divorciado(a)
# 34996  346992223569         Branca          E  59380-000  Divorciado(a)
# 34997  346992223569         Branca          E  59380-000  Divorciado(a)
# 34998  346992223569         Branca          E  59380-000  Divorciado(a)
# 34999  346992223569         Branca          E  59380-000  Divorciado(a)
# 35000  346992223569         Branca          E  59380-000  Divorciado(a)
# 35001  346992223569         Branca          E  59380-000  Divorciado(a)
# 35002  346992223569         Branca          E  59380-000  Divorciado(a)
# 35003  346992223569         Branca          E  59380-000  Divorciado(a)
# 35004  346992223569         Branca          E  59380-000  Divorciado(a)
# 35005  346992223569         Branca          E  59380-000  Divorciado(a)
# 35006  346992223569         Branca          E  59380-000  Divorciado(a)
# 35007  346992223569         Branca          E  59380-000  Divorciado(a)
# 35008  346992223569         Branca          E  59380-000  Divorciado(a)
# 35009  346992223569         Branca          E  59380-000  Divorciado(a)
# 35010  346992223569         Branca          E  59380-000  Divorciado(a)
# 35011  346992223569         Branca          E  59380-000  Divorciado(a)
# 35012  346992223569         Branca          E  59380-000  Divorciado(a)
# 35013  346992223569         Branca          E  59380-000  Divorciado(a)
# 35014  346992223569         Branca          E  59380-000  Divorciado(a)
#
#        media_final  percentual_frequencia  classe  \
# 0               85                  100.0     1.0
# 1               80                   90.0     1.0
# 2               83                  100.0     1.0
# 3               90                   85.0     1.0
# 4               67                  100.0     1.0
# 5               85                  100.0     1.0
# 6               74                   93.0     1.0
# 7               71                   93.0     1.0
# 8               71                   73.0     1.0
# 9              100                  100.0     1.0
# 10             100                   95.0     1.0
# 11              76                   76.0     1.0
# 12              75                   74.0     1.0
# 13              70                   70.0     1.0
# 14              81                   95.0     1.0
# 15              84                  100.0     1.0
# 16             100                   95.0     1.0
# 17              88                   95.0     1.0
# 18             100                  100.0     1.0
# 19               0                  100.0     0.0
# 20             100                  100.0     1.0
# 21              82                   95.0     1.0
# 22              80                  100.0     1.0
# 23              92                  100.0     1.0
# 24              71                  100.0     1.0
# 25              69                  100.0     1.0
# 26              73                  100.0     1.0
# 27              80                  100.0     1.0
# 28              94                  100.0     1.0
# 29              70                  100.0     1.0
# ...            ...                    ...     ...
# 34985            0                    0.0     0.0
# 34986            0                  100.0     0.0
# 34987            6                  100.0     0.0
# 34988            0                  100.0     0.0
# 34989           61                  100.0     1.0
# 34990           45                  100.0     1.0
# 34991           83                  100.0     1.0
# 34992           83                  100.0     1.0
# 34993           88                  100.0     1.0
# 34994           62                  100.0     1.0
# 34995           69                   68.0     1.0
# 34996           78                  100.0     1.0
# 34997           60                  100.0     1.0
# 34998           82                  100.0     1.0
# 34999           70                  100.0     1.0
# 35000           87                  100.0     1.0
# 35001           60                  100.0     1.0
# 35002           57                  100.0     1.0
# 35003           27                  100.0     0.0
# 35004           88                  100.0     1.0
# 35005           75                  100.0     1.0
# 35006           75                  100.0     1.0
# 35007           70                  100.0     1.0
# 35008           42                   97.0     1.0
# 35009            0                    1.0     0.0
# 35010           35                  100.0     0.0
# 35011            0                  100.0     0.0
# 35012            0                    1.0     0.0
# 35013            0                  100.0     0.0
# 35014            0                  100.0     0.0
#
#                                      descricao_historico  \
# 0                             Introdução ao Direito(60H)
# 1                Introdução à Segurança do Trabalho(60H)
# 2                  Desenvolvimento de Projeto Integrador
# 3                        Filosofia, Ciência e Tecnologia
# 4                                 Sociologia do Trabalho
# 5                 Seminário de Iniciação à Pesquisa(30H)
# 6                                Primeiros Socorros(60H)
# 7                            Psicologia do Trabalho(60H)
# 8                             Segurança do Trabalho(60H)
# 9      Seminário de Orientação para a Prática Profiss...
# 10          Gestão de Saúde e Segurança Ocupacional(60H)
# 11                              Higiene Ocupacional(60H)
# 12                                        Ergonomia(60H)
# 13     Direito Aplicado à Segurança e Saúde no Trabal...
# 14                                Saúde Ocupacional(30H)
# 15     Estatística Aplicada à Segurança do Trabalho(30H)
# 16                                 Psicologia Geral(30H)
# 17                                     Língua Portuguesa
# 18                                  Desenho Técnico(60H)
# 19                Seminário de Integração Acadêmica(10H)
# 20                                           Inglês(45H)
# 21                                      Informática(45H)
# 22                 Desenvolvimento de Projeto Integrador
# 23          Gestão de Saúde e Segurança Ocupacional(60H)
# 24                              Higiene Ocupacional(60H)
# 25                            Segurança do Trabalho(60H)
# 26     Direito Aplicado à Segurança e Saúde no Trabal...
# 27     Seminário de Orientação para a Prática Profiss...
# 28                                        Ergonomia(60H)
# 29                       Filosofia, Ciência e Tecnologia
# ...                                                  ...
# 34985                                 Educação Inclusiva
# 34986                             Literatura Espanhola I
# 34987                            Teoria da Literatura II
# 34988                     Literatura Hispano-Americana I
# 34989                          Fundamentos da Literatura
# 34990                               Língua Espanhola III
# 34991   Seminário de Orientação de Projeto Integrador II
# 34992        Desenvolvimento de Projetos Integradores II
# 34993                                           Latim II
# 34994  Fundamentos Sociopolíticos e Econômicos da Edu...
# 34995                             Psicologia da Educação
# 34996                                     Linguística II
# 34997                             Teoria da Literatura I
# 34998                Metodologia da Educação a Distância
# 34999                Fonética e Fonologia do Espanhol II
# 35000                                           Didática
# 35001                                Língua Espanhola II
# 35002                                    Morfossintaxe I
# 35003                       História da Língua Espanhola
# 35004                 Metodologia do Trabalho Científico
# 35005         Desenvolvimento de Projetos Integradores I
# 35006    Seminário de Orientação de Projeto Integrador I
# 35007                                    Linguística III
# 35008                                    Morfossintaxe I
# 35009       Atividades de Metodologia do Ensino de ELE I
# 35010                       História da Língua Espanhola
# 35011               Metodologia do Ensino de Literatura
# 35012          Metodologia do Ensino de Espanhol como LE
# 35013                                Mídias Educacionais
# 35014      Atividades de Metodologia do Ensino de ELE II
#
#                                                descricao  \
# 0      Técnico de Nível Médio em Segurança do Trabalh...
# 1      Técnico de Nível Médio em Segurança do Trabalh...
# 2      Técnico de Nível Médio em Segurança do Trabalh...
# 3      Técnico de Nível Médio em Segurança do Trabalh...
# 4      Técnico de Nível Médio em Segurança do Trabalh...
# 5      Técnico de Nível Médio em Segurança do Trabalh...
# 6      Técnico de Nível Médio em Segurança do Trabalh...
# 7      Técnico de Nível Médio em Segurança do Trabalh...
# 8      Técnico de Nível Médio em Segurança do Trabalh...
# 9      Técnico de Nível Médio em Segurança do Trabalh...
# 10     Técnico de Nível Médio em Segurança do Trabalh...
# 11     Técnico de Nível Médio em Segurança do Trabalh...
# 12     Técnico de Nível Médio em Segurança do Trabalh...
# 13     Técnico de Nível Médio em Segurança do Trabalh...
# 14     Técnico de Nível Médio em Segurança do Trabalh...
# 15     Técnico de Nível Médio em Segurança do Trabalh...
# 16     Técnico de Nível Médio em Segurança do Trabalh...
# 17     Técnico de Nível Médio em Segurança do Trabalh...
# 18     Técnico de Nível Médio em Segurança do Trabalh...
# 19     Técnico de Nível Médio em Segurança do Trabalh...
# 20     Técnico de Nível Médio em Segurança do Trabalh...
# 21     Técnico de Nível Médio em Segurança do Trabalh...
# 22     Técnico de Nível Médio em Segurança do Trabalh...
# 23     Técnico de Nível Médio em Segurança do Trabalh...
# 24     Técnico de Nível Médio em Segurança do Trabalh...
# 25     Técnico de Nível Médio em Segurança do Trabalh...
# 26     Técnico de Nível Médio em Segurança do Trabalh...
# 27     Técnico de Nível Médio em Segurança do Trabalh...
# 28     Técnico de Nível Médio em Segurança do Trabalh...
# 29     Técnico de Nível Médio em Segurança do Trabalh...
# ...                                                  ...
# 34985   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34986   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34987   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34988   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34989   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34990   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34991   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34992   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34993   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34994   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34995   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34996   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34997   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34998   Licenciatura em Letras Espanhol EaD - Campus EaD
# 34999   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35000   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35001   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35002   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35003   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35004   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35005   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35006   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35007   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35008   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35009   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35010   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35011   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35012   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35013   Licenciatura em Letras Espanhol EaD - Campus EaD
# 35014   Licenciatura em Letras Espanhol EaD - Campus EaD
#
#                    descricao_SM
# 0                   Matriculado
# 1                   Matriculado
# 2                   Matriculado
# 3                   Matriculado
# 4                   Matriculado
# 5                   Matriculado
# 6                   Matriculado
# 7                   Matriculado
# 8                   Matriculado
# 9                   Matriculado
# 10                  Matriculado
# 11                  Matriculado
# 12                  Matriculado
# 13                  Matriculado
# 14                  Matriculado
# 15                  Matriculado
# 16                  Matriculado
# 17                  Matriculado
# 18                  Matriculado
# 19                  Matriculado
# 20                  Matriculado
# 21                  Matriculado
# 22                  Matriculado
# 23                  Matriculado
# 24                  Matriculado
# 25                  Matriculado
# 26                  Matriculado
# 27                  Matriculado
# 28                  Matriculado
# 29                  Matriculado
# ...                         ...
# 34985  Trancado Voluntariamente
# 34986  Trancado Voluntariamente
# 34987  Trancado Voluntariamente
# 34988  Trancado Voluntariamente
# 34989  Trancado Voluntariamente
# 34990  Trancado Voluntariamente
# 34991  Trancado Voluntariamente
# 34992  Trancado Voluntariamente
# 34993  Trancado Voluntariamente
# 34994  Trancado Voluntariamente
# 34995  Trancado Voluntariamente
# 34996  Trancado Voluntariamente
# 34997  Trancado Voluntariamente
# 34998  Trancado Voluntariamente
# 34999  Trancado Voluntariamente
# 35000  Trancado Voluntariamente
# 35001  Trancado Voluntariamente
# 35002  Trancado Voluntariamente
# 35003  Trancado Voluntariamente
# 35004  Trancado Voluntariamente
# 35005  Trancado Voluntariamente
# 35006  Trancado Voluntariamente
# 35007  Trancado Voluntariamente
# 35008  Trancado Voluntariamente
# 35009  Trancado Voluntariamente
# 35010  Trancado Voluntariamente
# 35011  Trancado Voluntariamente
# 35012  Trancado Voluntariamente
# 35013  Trancado Voluntariamente
# 35014  Trancado Voluntariamente
#
# [34933 rows x 11 columns]>

# %%
#gerar gráficos
# %matplotlib inline
plt.close('all')

sns.violinplot(df['media_final'])

for index1, group1 in df.groupby(['descricao']):    
    fig = plt.figure()
    sns.plt.suptitle(index1)
    sns.violinplot(df[df.descricao == index1]['media_final'])

# %%
#test de normalidade
#stats.normaltest

#test se duas amostras são da mesma distribuição
df_ind0 = pd.DataFrame()
df_ind1 = pd.DataFrame()

#dois loops para testar par a par entre os cursos
for index1, group1 in df.groupby(['descricao']):      
    arr_test0 = []
    arr_test1 = []
    
    for index2, group2 in df.groupby(['descricao']):
        mf10 = df[(df.descricao == index1) & (df.classe == 0)]['media_final']
        mf20 = df[(df.descricao == index2) & (df.classe == 0)]['media_final']
        
        mf11 = df[(df.descricao == index1) & (df.classe == 1)]['media_final']
        mf21 = df[(df.descricao == index2) & (df.classe == 1)]['media_final']
    
        arr_test0.append( stats.ttest_ind(mf10,mf20).pvalue )
        arr_test1.append( stats.ttest_ind(mf11,mf21).pvalue )
        
    #salvando os testes
    df_ind0[index1] = arr_test0
    df_ind1[index1] = arr_test1    
    #break

# %%
#grafico de testes
f, ax = plt.subplots(figsize=(15, 15))
sns.heatmap(df_ind0)

# %%
#verificar quantidade de amostras necessárias
merged = pd.merge(df_Notas, df_Disciplina, left_on="disciplina_id", right_on="id", suffixes=["_L", "_R"])

#filtra disciplinas com registros maiores que 1
merged = merged.groupby('disciplina_id').filter(lambda x: len(x) > 1)

#criar coluna classe no merged
merged['classe'] = np.ones(merged.shape[0])*-1

#n_min
n = []

#definir linha que divide os clusters (alunos bons e ruins)
for index1, group1 in merged.groupby(['disciplina_id']):    
    
    #recuperando as notas apenas daquela disciplina    
    data = merged[merged.disciplina_id == index1]['media_final']
    
    #recuperando os clusters
    cluster = KMeans(n_clusters=2, init=np.array([[0], [10]]))
    cluster.fit(data.reshape(-1,1))
    
    #atribuindo a classe
    merged.loc[merged.disciplina_id == index1, 'classe'] = cluster.predict(data.reshape(-1,1))
    
    #testando a quantidade de amostras
    mf0 = merged[(merged.disciplina_id == index1) & (merged.classe == 0)]['media_final']
    mf1 = merged[(merged.disciplina_id == index1) & (merged.classe == 1)]['media_final']
    
    n.append( ((2.306*mf0.std())/2)**2 )
    n.append( ((2.306*mf1.std())/2)**2 ) 
    
print(max(n))
print(min(n))
#(1.96*0.3/0.1)**2
