# %%
import itertools

# Pandas
import pandas as pd

# Numpy
import numpy as np

# missingno - Visualização completude dados
# https://github.com/ResidentMario/missingno
import missingno as msno
# %matplotlib inline

# Bokeh
# Instalação: 
# $ conda install bokeh
# ou
# $ pip install bokeh
from bokeh.plotting import figure, show, output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="bbb740f0-d99c-4544-bc95-156e4c86ff92">Loading BokehJS ...</span>
#     </div>

# %%
# Importação dos dados
df_Aluno = pd.read_json('thiago/Aluno.json')
df_BeneficioGovernoFederal = pd.read_json("data/BeneficioGovernoFederal.json")
df_Caracterizacao = pd.read_json("data/Caracterizacao.json")
df_CompanhiaDomiciliar = pd.read_json("data/CompanhiaDomiciliar.json")
df_ContribuinteRendaFamiliar = pd.read_json("data/ContribuinteRendaFamiliar.json")
df_CursoCampus = pd.read_json("data/CursoCampus.json")
df_EstadoCivil = pd.read_json("data/EstadoCivil.json")
df_Idioma = pd.read_json("data/Idioma.json")
df_MatriculaPeriodo = pd.read_json("data/MatriculaPeriodo.json")
df_MeioTransporte = pd.read_json("data/MeioTransporte.json")
df_NecessidadeEspecial = pd.read_json("data/NecessidadeEspecial.json")
df_Raca = pd.read_json("data/Raca.json")
df_RazaoAfastamentoEducacional = pd.read_json("data/RazaoAfastamentoEducacional.json")
df_SituacaoMatricula = pd.read_json("data/SituacaoMatricula.json")
df_SituacaoMatriculaPeriodo = pd.read_json("data/SituacaoMatriculaPeriodo.json")
df_SituacaoTrabalho = pd.read_json("data/SituacaoTrabalho.json")
df_TipoAcessoInternet = pd.read_json("data/TipoAcessoInternet.json")
df_TipoAreaResidencial = pd.read_json("data/TipoAreaResidencial.json")
df_TipoEscola = pd.read_json("data/TipoEscola.json")
df_TipoImovelResidencial = pd.read_json("data/TipoImovelResidencial.json")
df_TipoServicoSaude = pd.read_json("data/TipoServicoSaude.json")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-9873c0074d65> in <module>()
#       1 # Importação dos dados
# ----> 2 df_Aluno = pd.read_json('data/Aluno.json')
#       3 df_BeneficioGovernoFederal = pd.read_json("data/BeneficioGovernoFederal.json")
#       4 df_Caracterizacao = pd.read_json("data/Caracterizacao.json")
#       5 df_CompanhiaDomiciliar = pd.read_json("data/CompanhiaDomiciliar.json")
#
# C:\Users\Thiago\Anaconda3\lib\site-packages\pandas\io\json.py in read_json(path_or_buf, orient, typ, dtype, convert_axes, convert_dates, keep_default_dates, numpy, precise_float, date_unit, encoding, lines)
#     279         obj = FrameParser(json, orient, dtype, convert_axes, convert_dates,
#     280                           keep_default_dates, numpy, precise_float,
# --> 281                           date_unit).parse()
#     282
#     283     if typ == 'series' or obj is None:
#
# C:\Users\Thiago\Anaconda3\lib\site-packages\pandas\io\json.py in parse(self)
#     347
#     348         else:
# --> 349             self._parse_no_numpy()
#     350
#     351         if self.obj is None:
#
# C:\Users\Thiago\Anaconda3\lib\site-packages\pandas\io\json.py in _parse_no_numpy(self)
#     564         if orient == "columns":
#     565             self.obj = DataFrame(
# --> 566                 loads(json, precise_float=self.precise_float), dtype=None)
#     567         elif orient == "split":
#     568             decoded = dict((str(k), v)
#
# ValueError: Expected object or value

# %%
#merge entre as tabelas 
df = pd.merge(df_Caracterizacao, df_Aluno, left_on="aluno_id", right_on="id", suffixes=["_L", "_R"])
df = pd.merge(df, df_CursoCampus, left_on="curso_campus_id", right_on="id", suffixes=["_L", "_curso"])
df = pd.merge(df, df_Raca, left_on="raca_id", right_on="id", suffixes=["_curso", "_raca"])
df = pd.merge(df, df_EstadoCivil, left_on="estado_civil_id", right_on="id")
df = pd.merge(df, df_SituacaoMatricula, left_on="situacao_id", right_on="id", suffixes=["_civil", "_situacao"])

#filtrando dados
df_Perfil_Situacao = df[['renda_per_capita', 'descricao_raca', 'descricao_civil', 'descricao_situacao']]
df_Perfil_Situacao

# %%
racas = ["Parda", "Preta", "Branca", "Indígena", "Amarela", "Não declarado"]
estados_civis = ["Solteiro(a)", "Casado(a)", "União Estável", "Divorciado(a)", "Viúvo(a)", "Não declarado"]

# %%
df_Perfil_Matriculado = df_Perfil_Situacao[df_Perfil_Situacao.descricao_situacao == "Matriculado"][['descricao_raca', 'descricao_civil', 'renda_per_capita']]
# df_Perfil_Matriculado
renda = df_Perfil_Matriculado.groupby(['descricao_raca', 'descricao_civil']).aggregate(['mean', 'count'])
renda['renda_per_capita']['mean']
# renda
df_Perfil_Matriculado =df_Perfil_Matriculado.dropna()
msno.matrix(df_Perfil_Matriculado)

# %%
x_raca = []
y_estado_civil = []
renda_media_per_capita = []
qtd_alunos_situacao = []

max_renda = 20
max_qtd = renda['renda_per_capita']['count'].max()
for raca, estado_civil in itertools.product(racas, estados_civis):
    x_raca.append(raca)
    y_estado_civil.append(estado_civil)
    if (raca, estado_civil) in renda['renda_per_capita']['mean'].index:
        renda_media_norm = renda['renda_per_capita']['mean'][raca][estado_civil]/max_renda
        cor_base_renda = renda_media_norm * 255
        renda_media_per_capita.append("#%02x%02x%02x" % (int(255 - cor_base_renda), int(cor_base_renda), 0))
        qtd_alunos_situacao.append(.9*(renda['renda_per_capita']['count'][raca][estado_civil]/max_qtd) + .1)
    else:
        renda_media_per_capita.append("#FFFFFF")
        qtd_alunos_situacao.append(0)

hm = figure(title="Perfil situação matriculado",
            tools="hover",
            toolbar_location=None,
            x_range=racas,
            y_range=estados_civis)

hm.rect(x_raca,
        y_estado_civil,
        color=renda_media_per_capita,
        alpha=np.ceil(qtd_alunos_situacao),
        fill_alpha=qtd_alunos_situacao, line_width=4,
        width=.96,
        height=.96)

show(hm)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="318d427d-5804-4fa3-acae-b5eae8b3e3ca"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("318d427d-5804-4fa3-acae-b5eae8b3e3ca");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("318d427d-5804-4fa3-acae-b5eae8b3e3ca");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '318d427d-5804-4fa3-acae-b5eae8b3e3ca' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"7fd1dfda-7b9f-461c-ad5b-5efa94147a30":{"roots":{"references":[{"attributes":{},"id":"f3509b68-8f2e-47f1-a9ef-386e564cdee2","type":"CategoricalTicker"},{"attributes":{"below":[{"id":"98d5f483-0496-4f8d-80c1-ec789a480be2","type":"CategoricalAxis"}],"left":[{"id":"a1bec7d9-c16a-4c10-a033-298ce016f31a","type":"CategoricalAxis"}],"renderers":[{"id":"98d5f483-0496-4f8d-80c1-ec789a480be2","type":"CategoricalAxis"},{"id":"cd4eaa6e-251d-4729-9d9d-abe557192566","type":"Grid"},{"id":"a1bec7d9-c16a-4c10-a033-298ce016f31a","type":"CategoricalAxis"},{"id":"cf577d23-f69a-4f5f-b243-402ef5ecdc25","type":"Grid"},{"id":"259a77af-f861-4dc3-99b4-0a86f04ea724","type":"GlyphRenderer"}],"title":{"id":"ebf64a61-2204-4759-99ac-4f633f9be41f","type":"Title"},"tool_events":{"id":"a3c30005-9485-4766-9d36-f04f2e85f9a1","type":"ToolEvents"},"toolbar":{"id":"1f8000c5-2261-48e7-959d-5ec89bd872ad","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"208b9804-237a-40a5-99e9-263bc4ed3399","type":"FactorRange"},"x_scale":{"id":"2ab82dfe-a7be-4a42-bba2-8c57c5275c41","type":"CategoricalScale"},"y_range":{"id":"af65827f-b15e-4f89-b39d-e171a88e266a","type":"FactorRange"},"y_scale":{"id":"416356ae-911f-4d5f-a073-349e0bdf6f7a","type":"CategoricalScale"}},"id":"c5be0205-6acd-4e7a-a81b-816c3f713979","subtype":"Figure","type":"Plot"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.96},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"line_width":{"value":4},"width":{"units":"data","value":0.96},"x":{"field":"x"},"y":{"field":"y"}},"id":"566f25e5-9e81-4589-b9ff-1fbc9c9f7755","type":"Rect"},{"attributes":{"callback":null,"plot":{"id":"c5be0205-6acd-4e7a-a81b-816c3f713979","subtype":"Figure","type":"Plot"}},"id":"0c0f194f-f455-4db6-b673-a045a688d2c2","type":"HoverTool"},{"attributes":{"fill_alpha":{"field":"fill_alpha"},"fill_color":{"field":"fill_color"},"height":{"units":"data","value":0.96},"line_alpha":{"field":"line_alpha"},"line_color":{"field":"line_color"},"line_width":{"value":4},"width":{"units":"data","value":0.96},"x":{"field":"x"},"y":{"field":"y"}},"id":"ba6dfc20-4a2f-47e4-852e-49ad6495e7cd","type":"Rect"},{"attributes":{"callback":null,"factors":["Parda","Preta","Branca","Ind\u00edgena","Amarela","N\u00e3o declarado"]},"id":"208b9804-237a-40a5-99e9-263bc4ed3399","type":"FactorRange"},{"attributes":{"data_source":{"id":"4e6c3c26-d52f-406a-9d53-5378792ebd90","type":"ColumnDataSource"},"glyph":{"id":"ba6dfc20-4a2f-47e4-852e-49ad6495e7cd","type":"Rect"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"566f25e5-9e81-4589-b9ff-1fbc9c9f7755","type":"Rect"},"selection_glyph":null},"id":"259a77af-f861-4dc3-99b4-0a86f04ea724","type":"GlyphRenderer"},{"attributes":{},"id":"2ab82dfe-a7be-4a42-bba2-8c57c5275c41","type":"CategoricalScale"},{"attributes":{"plot":{"id":"c5be0205-6acd-4e7a-a81b-816c3f713979","subtype":"Figure","type":"Plot"},"ticker":{"id":"f3509b68-8f2e-47f1-a9ef-386e564cdee2","type":"CategoricalTicker"}},"id":"cd4eaa6e-251d-4729-9d9d-abe557192566","type":"Grid"},{"attributes":{},"id":"a3c30005-9485-4766-9d36-f04f2e85f9a1","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Perfil situa\u00e7\u00e3o matriculado"},"id":"ebf64a61-2204-4759-99ac-4f633f9be41f","type":"Title"},{"attributes":{"callback":null,"column_names":["x","y","fill_color","line_color","fill_alpha","line_alpha"],"data":{"fill_alpha":[1.0,0.36005025125628143,0.17688442211055277,0.17462311557788945,0.10452261306532663,0.10452261306532663,0.235678391959799,0.1520100502512563,0.11582914572864322,0.12487437185929649,0,0.10226130653266333,0.7512562814070352,0.26733668341708544,0.14748743718592966,0.14974874371859298,0.10226130653266333,0.10452261306532663,0.10226130653266333,0,0,0.10226130653266333,0,0,0.1135678391959799,0.10904522613065327,0,0,0,0,0.13844221105527638,0.12035175879396985,0.10678391959798995,0.10678391959798995,0,0],"fill_color":["#dd2100","#e21c00","#5ba30 ...

# %%
x_raca = []
y_estado_civil = []
renda_media_per_capita = []
qtd_alunos_situacao = []

# print(renda.index)
# print(renda)

max_renda = 20
max_qtd = renda['renda_per_capita']['count'].max()
for raca, estado_civil in itertools.product(racas, estados_civis):
    x_raca.append(raca)
    y_estado_civil.append(estado_civil)
    if (raca, estado_civil) in renda['renda_per_capita']['mean'].index:
        renda_media_norm = renda['renda_per_capita']['mean'][raca][estado_civil]/max_renda
        cor_base_renda = renda_media_norm * 255
        renda_media_per_capita.append("#%02x%02x%02x" % (int(255 - cor_base_renda), int(cor_base_renda), 0))
        qtd_alunos_situacao.append(.9 * (renda['renda_per_capita']['count'][raca][estado_civil]/max_qtd) + .1)
    else:
        renda_media_per_capita.append("#FFFFF")
        qtd_alunos_situacao.append(0)

hm = figure(title="Perfil situação matriculado",
            tools="hover",
            toolbar_location=None,
            x_range=racas,
            y_range=estados_civis)

hm.rect(x_raca,
           y_estado_civil,
           color=renda_media_per_capita,
           fill_alpha=1,
           width=qtd_alunos_situacao,
           height=qtd_alunos_situacao)

# print(racas)
show(hm)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="9fadfa76-87f2-4bed-a9a7-28b37c896333"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("9fadfa76-87f2-4bed-a9a7-28b37c896333");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("9fadfa76-87f2-4bed-a9a7-28b37c896333");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '9fadfa76-87f2-4bed-a9a7-28b37c896333' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"ff11496f-4a25-46dc-9905-c5eedc86a641":{"roots":{"references":[{"attributes":{"formatter":{"id":"0cfea665-59a4-4072-998e-8a39800e5a7d","type":"CategoricalTickFormatter"},"plot":{"id":"62db67aa-343f-4e36-b200-2da7e1a7fdf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"868c829f-c939-43e8-81f5-a4b536c00360","type":"CategoricalTicker"}},"id":"b1a82168-2499-4cdc-bb4b-9ce2a81a00d6","type":"CategoricalAxis"},{"attributes":{},"id":"f7227910-2343-4ac5-893e-ba8637fc2437","type":"ToolEvents"},{"attributes":{"plot":null,"text":"Perfil situa\u00e7\u00e3o matriculado"},"id":"96b3907e-c986-434b-9dfc-450855de250e","type":"Title"},{"attributes":{"dimension":1,"plot":{"id":"62db67aa-343f-4e36-b200-2da7e1a7fdf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7c758a8-e35d-466e-8311-56f2294b86a8","type":"CategoricalTicker"}},"id":"2404f70f-e5ee-4b53-be8b-bd1cd415161d","type":"Grid"},{"attributes":{},"id":"0cfea665-59a4-4072-998e-8a39800e5a7d","type":"CategoricalTickFormatter"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"ee0f9215-49cf-4f76-b8b9-cf65d81477bc","type":"HoverTool"}]},"id":"1e204948-368b-4113-a045-2df3c0e898d2","type":"Toolbar"},{"attributes":{"fill_color":{"field":"fill_color"},"height":{"field":"height","units":"data"},"line_color":{"field":"line_color"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"6f3adfb8-ee2c-490c-b125-4c4d4b9fe030","type":"Rect"},{"attributes":{},"id":"a855ed36-ff06-454f-9edb-11e34ef706c5","type":"CategoricalScale"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"field":"height","units":"data"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"field":"width","units":"data"},"x":{"field":"x"},"y":{"field":"y"}},"id":"3e2a0713-d0d9-4cce-8b08-82ba02ec5e50","type":"Rect"},{"attributes":{},"id":"868c829f-c939-43e8-81f5-a4b536c00360","type":"CategoricalTicker"},{"attributes":{"callback":null,"plot":{"id":"62db67aa-343f-4e36-b200-2da7e1a7fdf6","subtype":"Figure","type":"Plot"}},"id":"ee0f9215-49cf-4f76-b8b9-cf65d81477bc","type":"HoverTool"},{"attributes":{},"id":"b2ef32bd-f00a-4723-9636-3e2233a49179","type":"CategoricalScale"},{"attributes":{"callback":null,"factors":["Parda","Preta","Branca","Ind\u00edgena","Amarela","N\u00e3o declarado"]},"id":"b92c385c-e274-4875-916b-ad7781aba071","type":"FactorRange"},{"attributes":{"formatter":{"id":"94403260-bfee-465d-a8f5-863d12545719","type":"CategoricalTickFormatter"},"plot":{"id":"62db67aa-343f-4e36-b200-2da7e1a7fdf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"a7c758a8-e35d-466e-8311-56f2294b86a8","type":"CategoricalTicker"}},"id":"36683d5e-8868-479b-9527-e77c73ddfae4","type":"CategoricalAxis"},{"attributes":{},"id":"94403260-bfee-465d-a8f5-863d12545719","type":"CategoricalTickFormatter"},{"attributes":{},"id":"a7c758a8-e35d-466e-8311-56f2294b86a8","type":"CategoricalTicker"},{"attributes":{"plot":{"id":"62db67aa-343f-4e36-b200-2da7e1a7fdf6","subtype":"Figure","type":"Plot"},"ticker":{"id":"868c829f-c939-43e8-81f5-a4b536c00360","type":"CategoricalTicker"}},"id":"42e5cb83-93b5-4445-adb5-1d4e027c3887","type":"Grid"},{"attributes":{"callback":null,"factors":["Solteiro(a)","Casado(a)","Uni\u00e3o Est\u00e1vel","Divorciado(a)","Vi\u00favo(a)","N\u00e3o declarado"]},"id":"ced5533c-64c2-4611-8c85-333182acf1eb","type":"FactorRange"},{"attributes":{"below":[{"id":"b1a82168-2499-4cdc-bb4b-9ce2a81a00d6","type":"CategoricalAxis"}],"left":[{"id":"36683d5e-8868-479b-9527-e77c73ddfae4","type":"CategoricalAxis"}],"renderers":[{"id":"b1a82168-2499-4cdc-bb4b-9ce2a81a00d6","type":"CategoricalAxis"},{"id":"42e5cb83-93b5-4445-adb5-1d4e027c3887","type":"Grid"},{"id":"36683d5e-8868-479b-9527-e77c73ddfae4","type":"CategoricalAxis"},{"id":"2404f70f-e5ee-4b53-be8b-bd1cd415161d","type":"Grid"},{"id":"2c493173-4662-4dfe-bdc0-5d8bc75e64fd","type":"GlyphRenderer"}],"title":{"id":"96b3907e-c986-4 ...

# %%
x_raca = []
y_estado_civil = []
cor_renda_per_capita = []
qtd_alunos_situacao = []

# print(renda.index)
# print(renda)

max_renda = 20
max_qtd = renda['renda_per_capita']['count'].max()
for index, linha in df_Perfil_Matriculado.iterrows():
    x_raca.append(racas.index(linha['descricao_raca']) + .55 + .9*np.random.uniform())
    y_estado_civil.append(estados_civis.index(linha['descricao_civil']) + .55 + .9*np.random.uniform())
    renda_media_norm = renda['renda_per_capita']['mean'][linha['descricao_raca']][linha['descricao_civil']]/max_renda
    cor_base_renda = renda_media_norm * 255
    cor_renda_per_capita.append("#%02x%02x%02x" % (int(255 - cor_base_renda), int(cor_base_renda), 0))

hm = figure(title="Perfil situação matriculado",
            tools="hover",
            toolbar_location=None,
            x_range=racas,
            y_range=estados_civis)

x_quadrados = []
y_quadrados = []
cor_quadrados = []
for x, y in itertools.product(range(1, 7), range(1, 7)):
    x_quadrados.append(x)
    y_quadrados.append(y)
    cor_quadrados.append("#DEDEDE" if ((x + y) % 2 == 0) else "#EDEDED")
    
hm.rect(x_quadrados,
        y_quadrados,
        color="#CDCDCD",
        fill_color=cor_quadrados,
        width=1,
        height=1)

hm.ellipse(x_raca,
           y_estado_civil,
           color=cor_renda_per_capita,
           fill_alpha=.4,
           width=.1,
           height=.1)

show(hm)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="aafb9f18-d3ef-4f19-a829-ee319a86bb65"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         var el = document.getElementById("aafb9f18-d3ef-4f19-a829-ee319a86bb65");
#         el.textContent = "BokehJS " + Bokeh.version + " successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       try {
#         window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       }
#       finally {
#         delete window._bokeh_onload_callbacks
#       }
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("aafb9f18-d3ef-4f19-a829-ee319a86bb65");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'aafb9f18-d3ef-4f19-a829-ee319a86bb65' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"99f4a6b8-3c9d-4c34-acc3-640376fffa0e":{"roots":{"references":[{"attributes":{},"id":"5dc6d23e-90f2-43ba-bef0-5c650a55ceea","type":"CategoricalTickFormatter"},{"attributes":{},"id":"34ef49e1-17d7-4662-81b3-cad0e8b1bd78","type":"CategoricalTicker"},{"attributes":{},"id":"1e0635fb-944f-4a38-8948-ac5be447b23f","type":"CategoricalTickFormatter"},{"attributes":{"below":[{"id":"2d8f0680-614e-4d40-b8f0-333a25e61021","type":"CategoricalAxis"}],"left":[{"id":"bce128bd-4f79-4b34-9ea8-26bdff300ef3","type":"CategoricalAxis"}],"renderers":[{"id":"2d8f0680-614e-4d40-b8f0-333a25e61021","type":"CategoricalAxis"},{"id":"f37e1c90-dbf9-4e09-9ee9-758d7fc38da8","type":"Grid"},{"id":"bce128bd-4f79-4b34-9ea8-26bdff300ef3","type":"CategoricalAxis"},{"id":"1c71e97b-8ec5-4a90-bcaa-5d288693c5bf","type":"Grid"},{"id":"9bd5e320-86a9-4f3d-b149-18ca4187364d","type":"GlyphRenderer"},{"id":"1964ab84-3e0c-4ffb-a93d-06820c222175","type":"GlyphRenderer"}],"title":{"id":"71c96c15-46dd-4abe-9da3-81b729cfcb18","type":"Title"},"tool_events":{"id":"d378f045-fe69-4c82-a1d9-0b3cb80b4641","type":"ToolEvents"},"toolbar":{"id":"5411b2ef-d44c-420d-baee-c96a50a08fa8","type":"Toolbar"},"toolbar_location":null,"x_range":{"id":"735af5b5-7156-428c-9307-9c7782abd1d4","type":"FactorRange"},"x_scale":{"id":"f3cd69db-3f80-49e4-b547-51b382c14005","type":"CategoricalScale"},"y_range":{"id":"ddc2bb87-a060-41c0-a1fd-58306365b37c","type":"FactorRange"},"y_scale":{"id":"c11cd986-bc38-4538-84ad-d8fcb9aa5cfb","type":"CategoricalScale"}},"id":"3c6fe439-1dbe-48ec-a9fe-2b6c3b5ed1d5","subtype":"Figure","type":"Plot"},{"attributes":{"dimension":1,"plot":{"id":"3c6fe439-1dbe-48ec-a9fe-2b6c3b5ed1d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"31f1003e-2bde-4e18-a248-0dcd74713c81","type":"CategoricalTicker"}},"id":"1c71e97b-8ec5-4a90-bcaa-5d288693c5bf","type":"Grid"},{"attributes":{"fill_color":{"field":"fill_color"},"height":{"units":"data","value":1},"line_color":{"value":"#CDCDCD"},"width":{"units":"data","value":1},"x":{"field":"x"},"y":{"field":"y"}},"id":"f1f79f32-8ed3-4022-ae4f-4ffb1eadb445","type":"Rect"},{"attributes":{},"id":"31f1003e-2bde-4e18-a248-0dcd74713c81","type":"CategoricalTicker"},{"attributes":{"plot":null,"text":"Perfil situa\u00e7\u00e3o matriculado"},"id":"71c96c15-46dd-4abe-9da3-81b729cfcb18","type":"Title"},{"attributes":{},"id":"c11cd986-bc38-4538-84ad-d8fcb9aa5cfb","type":"CategoricalScale"},{"attributes":{"callback":null,"plot":{"id":"3c6fe439-1dbe-48ec-a9fe-2b6c3b5ed1d5","subtype":"Figure","type":"Plot"}},"id":"c50a6cd8-4fb4-496f-a4a1-b5e97ebf2a23","type":"HoverTool"},{"attributes":{"active_drag":"auto","active_inspect":"auto","active_scroll":"auto","active_tap":"auto","tools":[{"id":"c50a6cd8-4fb4-496f-a4a1-b5e97ebf2a23","type":"HoverTool"}]},"id":"5411b2ef-d44c-420d-baee-c96a50a08fa8","type":"Toolbar"},{"attributes":{"data_source":{"id":"f7e3b2ab-87cf-4320-b268-b42965b1af92","type":"ColumnDataSource"},"glyph":{"id":"504e4f83-5e46-4d19-b879-d36cbc903106","type":"Ellipse"},"hover_glyph":null,"muted_glyph":null,"nonselection_glyph":{"id":"773bbefd-48e5-4955-a132-e23c42603a0a","type":"Ellipse"},"selection_glyph":null},"id":"1964ab84-3e0c-4ffb-a93d-06820c222175","type":"GlyphRenderer"},{"attributes":{"formatter":{"id":"1e0635fb-944f-4a38-8948-ac5be447b23f","type":"CategoricalTickFormatter"},"plot":{"id":"3c6fe439-1dbe-48ec-a9fe-2b6c3b5ed1d5","subtype":"Figure","type":"Plot"},"ticker":{"id":"31f1003e-2bde-4e18-a248-0dcd74713c81","type":"CategoricalTicker"}},"id":"bce128bd-4f79-4b34-9ea8-26bdff300ef3","type":"CategoricalAxis"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"height":{"units":"data","value":0.1},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"width":{"units":"data","value":0.1},"x":{"field":"x"},"y":{"field":"y"}},"id":"773bbefd-48e5-4955-a132-e23c42603a0a","type":"Ellipse"},{"attributes":{"callback":null,"factors":["Parda","Preta","Branca","Ind\u00edgena","Amarela","N\u00e3o declara ...
